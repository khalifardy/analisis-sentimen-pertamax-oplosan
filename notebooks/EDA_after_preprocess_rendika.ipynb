# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/processed/preprocessed_dataset_rendika.csv')

# %%
#distribusi label
print('\n Distribusi label')
print(df['Label'].value_counts())
print(f'\n Presentase')
print(df['Label'].value_counts(normalize=True))
# Out:
#  Distribusi label
# Label
# 0    24049
# 1     9126
# 2      510
# Name: count, dtype: int64
#
#  Presentase
# Label
# 0    0.713938
# 1    0.270922
# 2    0.015140
# Name: proportion, dtype: float64

# %%
df
# Out:
#                                               clean_text  Label  char_len  \
# 0      nyata bestienya koruptor kakap pertamina riva ...      0       244
# 1      salah satu lebih pertamax oplos rubah suara kn...      0        70
# 2                                               juga win      1        12
# 3      td pagi buka tiktok yang lucu sekarang konoha ...      0       130
# 4                  herman khaeron amplop pertamina oplos      0        43
# ...                                                  ...    ...       ...
# 33680  update klaseman liga korupsi indonesia pt pert...      0       250
# 33681  tidak takut korupsi skr bukan m lg rtsan t mkn...      0       189
# 33682     info pente klaseman liga korupsi indonesia lki      1        56
# 33683  klaseman korupsi edar revisi arti kasus posisi...      0        85
# 33684  sampai akhir tahun klasemen tidak ubah geser s...      0       274
#
#        word_count
# 0              38
# 1              10
# 2               3
# 3              22
# 4               6
# ...           ...
# 33680          37
# 33681          36
# 33682           8
# 33683          12
# 33684          43
#
# [33685 rows x 4 columns]

# %%
df2=df
df2['Label'] = df['Label'].map(
    {0:'negatif',1:'netral',2:'positif'}
)

# %%
#fig,axes = plt.subplots(1,2,figsize=(14,5))

#Pie Charts distribusi label
colors = {
    'positif': '#2ecc71',
    'negatif': '#e74c3c',
    'netral': '#3498db'
}

label_counts = df2['Label'].value_counts()
plt.pie(label_counts.values, labels=label_counts.index, autopct='%1.1f%%',
            colors=[colors[label] for label in label_counts.index])
plt.title('Distrbusi Sentiment')

plt.tight_layout()
plt.savefig('distribusi_label.png', dpi=300)
plt.show()

# %%
#panjang text per sentimen
df_only_text_clean = df2
df_only_text_clean['text_length'] = df_only_text_clean['clean_text'].apply(len)
df_only_text_clean.groupby('Label')['text_length'].mean()
# Out:
# Label
# negatif    101.378353
# netral      65.341004
# positif     61.374510
# Name: text_length, dtype: float64

# %%
from wordcloud import WordCloud

# %%
text = ' '.join(df_only_text_clean['clean_text'].astype(str))

#buat wordcloud

wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
).generate(text)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from matplotlib import colormaps

# %%
#sentimen negatif (label = 0)
text_negatif = ' '.join(df_only_text_clean[df_only_text_clean['Label']=='negatif']['clean_text'].astype(str))
wc_negatif = WordCloud(
    width=800,
    height=400,
    background_color='white',
    colormap = 'Reds'
).generate(text_negatif)

text_netral = ' '.join(df_only_text_clean[df_only_text_clean['Label']=='netral']['clean_text'].astype(str))
wc_netral = WordCloud(
    width=800,
    height=400,
    background_color='white',
    colormap = 'Blues'
).generate(text_netral)

text_positif = ' '.join(df_only_text_clean[df_only_text_clean['Label']=='positif']['clean_text'].astype(str))
wc_positif = WordCloud(
    width=800,
    height=400,
    background_color='white',
    colormap = 'Greens'
).generate(text_positif)


fig, axes = plt.subplots(1,3, figsize=(18,5))

axes[0].imshow(wc_negatif, interpolation='bilinear')
axes[0].set_title('Negatif')
axes[0].axis('off')

axes[1].imshow(wc_netral, interpolation='bilinear')
axes[1].set_title('Netral')
axes[1].axis('off')

axes[2].imshow(wc_positif, interpolation='bilinear')
axes[2].set_title('Positif')
axes[2].axis('off')

plt.tight_layout()
plt.show()
