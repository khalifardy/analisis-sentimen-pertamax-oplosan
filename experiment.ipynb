# %%
import importlib
import pandas as pd
import src.balancing as balancing

balancing = importlib.reload(balancing)
run_experiments_single_dataset = balancing.run_experiments_single_dataset
print(list(balancing.BALANCING_METHODS))
# Out:
# ['No_Balancing', 'ROS', 'SMOTE', 'RUS', 'SMOTEENN', 'SMOTETomek']

# %%
# =============================================================
# STEP 1: LOAD FINAL ADJUDICATED AND PREPROCESSED DATASET
# =============================================================

df_kesepakatan = pd.read_csv(
    "data/processed/preprocessed_dataset_kesepakatan.csv"
)

# Validasi sebelum eksperimen panjang
assert {"clean_text", "label"}.issubset(df_kesepakatan.columns)

df_kesepakatan = df_kesepakatan.dropna(
    subset=["clean_text", "label"]
).copy()

df_kesepakatan = df_kesepakatan[
    df_kesepakatan["clean_text"].astype(str).str.strip().ne("")
].copy()

df_kesepakatan["label"] = df_kesepakatan["label"].astype(int)

print(f"Loaded: {len(df_kesepakatan)} rows")
print(f"Columns: {df_kesepakatan.columns.tolist()}")
print(f"Label distribution: {df_kesepakatan['label'].value_counts().sort_index().to_dict()}")

assert len(df_kesepakatan) == 34_985
# Out:
# Loaded: 34985 rows
# Columns: ['clean_text', 'label']
# Label distribution: {0: 27350, 1: 6649, 2: 986}

# %%
import marimo as mo

# %% [markdown]
# #Eksperimen

# %%
all_results = run_experiments_single_dataset(df_kesepakatan, kolom_y='label')
# Out:
# ============================================================
# PREPARE FEATURES - Dataset
# ============================================================
#
# Dataset:
#   Shape fitur TF-IDF Train: (27988, 5000)
#   Shape fitur TF-IDF Test: (6997, 5000)
#   Jumlah fitur train: 5000
#   Jumlah fitur test: 5000
#
# ######################################################################
#   DATASET: Dataset
# ######################################################################
#
# >> Dataset | No_Balancing | MLP Baseline
#   Run 1/3 (seed=42)... WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# WARNING:tensorflow:From C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Acc=0.7186 | Weighted-F1=0.7140 | Macro-F1=0.4659
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.7157 | Weighted-F1=0.7101 | Macro-F1=0.4683
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.7006 | Weighted-F1=0.7007 | Macro-F1=0.4568
#   >> RATA-RATA: Acc=0.7116 (±0.0079) | Weighted-F1=0.7083 (±0.0056) | Macro-F1=0.4636 (±0.0050)
#
# >> Dataset | No_Balancing | MLP Advanced
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.7965 | Weighted-F1=0.7422 | Macro-F1=0.4619
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.7976 | Weighted-F1=0.7512 | Macro-F1=0.4720
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.7955 | Weighted-F1=0.7457 | Macro-F1=0.4675
#   >> RATA-RATA: Acc=0.7965 (±0.0009) | Weighted-F1=0.7464 (±0.0037) | Macro-F1=0.4671 (±0.0041)
#
# >> Dataset | No_Balancing | MLP Keras Tuner
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 13s 62ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.7936 | Weighted-F1=0.7311 | Macro-F1=0.4388
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 16s 74ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.7933 | Weighted-F1=0.7467 | Macro-F1=0.4650
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 13s 61ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.7931 | Weighted-F1=0.7454 | Macro-F1=0.4607
#   >> RATA-RATA: Acc=0.7933 (±0.0002) | Weighted-F1=0.7410 (±0.0071) | Macro-F1=0.4548 (±0.0115)
#
# >> Dataset | No_Balancing | Naive Bayes
#   Run 1/3 (seed=42)... Acc=0.7916 | Weighted-F1=0.7396 | Macro-F1=0.4525
#   Run 2/3 (seed=123)... Acc=0.7916 | Weighted-F1=0.7396 | Macro-F1=0.4525
#   Run 3/3 (seed=456)... Acc=0.7916 | Weighted-F1=0.7396 | Macro-F1=0.4525
#   >> RATA-RATA: Acc=0.7916 (±0.0000) | Weighted-F1=0.7396 (±0.0000) | Macro-F1=0.4525 (±0.0000)
#
# >> Dataset | No_Balancing | SVM
#   Run 1/3 (seed=42)... Acc=0.7956 | Weighted-F1=0.7423 | Macro-F1=0.4531
#   Run 2/3 (seed=123)... Acc=0.7956 | Weighted-F1=0.7423 | Macro-F1=0.4531
#   Run 3/3 (seed=456)... Acc=0.7956 | Weighted-F1=0.7423 | Macro-F1=0.4531
#   >> RATA-RATA: Acc=0.7956 (±0.0000) | Weighted-F1=0.7423 (±0.0000) | Macro-F1=0.4531 (±0.0000)
#
# >> Dataset | No_Balancing | Random Forest
#   Run 1/3 (seed=42)... Acc=0.7915 | Weighted-F1=0.7544 | Macro-F1=0.4839
#   Run 2/3 (seed=123)... Acc=0.7929 | Weighted-F1=0.7569 | Macro-F1=0.4880
#   Run 3/3 (seed=456)... Acc=0.7932 | Weighted-F1=0.7567 | Macro-F1=0.4860
#   >> RATA-RATA: Acc=0.7925 (±0.0008) | Weighted-F1=0.7560 (±0.0011) | Macro-F1=0.4860 (±0.0017)
#
# >> Dataset | No_Balancing | Logistic Regression
#   Run 1/3 (seed=42)... Acc=0.7968 | Weighted-F1=0.7503 | Macro-F1=0.4746
#   Run 2/3 (seed=123)... Acc=0.7968 | Weighted-F1=0.7503 | Macro-F1=0.4746
#   Run 3/3 (seed=456)... Acc=0.7968 | Weighted-F1=0.7503 | Macro-F1=0.4746
#   >> RATA-RATA: Acc=0.7968 (±0.0000) | Weighted-F1=0.7503 (±0.0000) | Macro-F1=0.4746 (±0.0000)
#
# >> Dataset | ROS | MLP Baseline
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.7530 | Weighted-F1=0.7292 | Macro-F1=0.4635
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.7423 | Weighted-F1=0.7250 | Macro-F1=0.4550
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.7489 | Weighted-F1=0.7279 | Macro-F1=0.4626
#   >> RATA-RATA: Acc=0.7481 (±0.0044) | Weighted-F1=0.7274 (±0.0017) | Macro-F1=0.4604 (±0.0038)
#
# >> Dataset | ROS | MLP Advanced
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Acc=0.7543 | Weighted-F1=0.7303 | Macro-F1=0.4590
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Acc=0.7580 | Weighted-F1=0.7302 | Macro-F1=0.4568
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Acc=0.7635 | Weighted-F1=0.7310 | Macro-F1=0.4556
#   >> RATA-RATA: Acc=0.7586 (±0.0038) | Weighted-F1=0.7305 (±0.0003) | Macro-F1=0.4571 (±0.0014)
#
# >> Dataset | ROS | MLP Keras Tuner
#   Run 1/3 (seed=42)...
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.7146 | Weighted-F1=0.7122 | Macro-F1=0.4347
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 13s 64ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.7393 | Weighted-F1=0.7250 | Macro-F1=0.4629
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 19s 91ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.7620 | Weighted-F1=0.7302 | Macro-F1=0.4505
#   >> RATA-RATA: Acc=0.7386 (±0.0194) | Weighted-F1=0.7225 (±0.0076) | Macro-F1=0.4494 (±0.0115)
#
# >> Dataset | ROS | Naive Bayes
#   Run 1/3 (seed=42)... Acc=0.6511 | Weighted-F1=0.6810 | Macro-F1=0.4481
#   Run 2/3 (seed=123)... Acc=0.6504 | Weighted-F1=0.6804 | Macro-F1=0.4485
#   Run 3/3 (seed=456)... Acc=0.6519 | Weighted-F1=0.6810 | Macro-F1=0.4465
#   >> RATA-RATA: Acc=0.6511 (±0.0006) | Weighted-F1=0.6808 (±0.0003) | Macro-F1=0.4477 (±0.0009)
#
# >> Dataset | ROS | SVM
#   Run 1/3 (seed=42)... Acc=0.6193 | Weighted-F1=0.6557 | Macro-F1=0.4273
#   Run 2/3 (seed=123)... Acc=0.6177 | Weighted-F1=0.6545 | Macro-F1=0.4273
#   Run 3/3 (seed=456)... Acc=0.6147 | Weighted-F1=0.6523 | Macro-F1=0.4256
#   >> RATA-RATA: Acc=0.6172 (±0.0019) | Weighted-F1=0.6542 (±0.0014) | Macro-F1=0.4267 (±0.0008)
#
# >> Dataset | ROS | Random Forest
#   Run 1/3 (seed=42)... Acc=0.7798 | Weighted-F1=0.7628 | Macro-F1=0.5098
#   Run 2/3 (seed=123)... Acc=0.7782 | Weighted-F1=0.7606 | Macro-F1=0.5085
#   Run 3/3 (seed=456)... Acc=0.7775 | Weighted-F1=0.7604 | Macro-F1=0.5096
#   >> RATA-RATA: Acc=0.7785 (±0.0010) | Weighted-F1=0.7612 (±0.0011) | Macro-F1=0.5093 (±0.0006)
#
# >> Dataset | ROS | Logistic Regression
#   Run 1/3 (seed=42)... Acc=0.6108 | Weighted-F1=0.6503 | Macro-F1=0.4205
#   Run 2/3 (seed=123)... Acc=0.6093 | Weighted-F1=0.6492 | Macro-F1=0.4210
#   Run 3/3 (seed=456)... Acc=0.6128 | Weighted-F1=0.6525 | Macro-F1=0.4239
#   >> RATA-RATA: Acc=0.6110 (±0.0015) | Weighted-F1=0.6507 (±0.0014) | Macro-F1=0.4218 (±0.0015)
#
# >> Dataset | SMOTE | MLP Baseline
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.7723 | Weighted-F1=0.7284 | Macro-F1=0.4433
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.7718 | Weighted-F1=0.7216 | Macro-F1=0.4326
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.7646 | Weighted-F1=0.7205 | Macro-F1=0.4337
#   >> RATA-RATA: Acc=0.7696 (±0.0035) | Weighted-F1=0.7235 (±0.0035) | Macro-F1=0.4365 (±0.0048)
#
# >> Dataset | SMOTE | MLP Advanced
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Acc=0.7219 | Weighted-F1=0.7127 | Macro-F1=0.4497
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Acc=0.7403 | Weighted-F1=0.7242 | Macro-F1=0.4573
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.7425 | Weighted-F1=0.7283 | Macro-F1=0.4676
#   >> RATA-RATA: Acc=0.7349 (±0.0092) | Weighted-F1=0.7217 (±0.0066) | Macro-F1=0.4582 (±0.0073)
#
# >> Dataset | SMOTE | MLP Keras Tuner
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 20s 92ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.7330 | Weighted-F1=0.7216 | Macro-F1=0.4545
#   Run 2/3 (seed=123)...
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.7399 | Weighted-F1=0.7243 | Macro-F1=0.4560
#   Run 3/3 (seed=456)...
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.7332 | Weighted-F1=0.7199 | Macro-F1=0.4467
#   >> RATA-RATA: Acc=0.7354 (±0.0032) | Weighted-F1=0.7219 (±0.0018) | Macro-F1=0.4524 (±0.0041)
#
# >> Dataset | SMOTE | Naive Bayes
#   Run 1/3 (seed=42)... Acc=0.6580 | Weighted-F1=0.6853 | Macro-F1=0.4488
#   Run 2/3 (seed=123)... Acc=0.6637 | Weighted-F1=0.6890 | Macro-F1=0.4551
#   Run 3/3 (seed=456)... Acc=0.6626 | Weighted-F1=0.6879 | Macro-F1=0.4526
#   >> RATA-RATA: Acc=0.6614 (±0.0025) | Weighted-F1=0.6874 (±0.0016) | Macro-F1=0.4522 (±0.0026)
#
# >> Dataset | SMOTE | SVM
#   Run 1/3 (seed=42)... Acc=0.6771 | Weighted-F1=0.6990 | Macro-F1=0.4425
#   Run 2/3 (seed=123)... Acc=0.6757 | Weighted-F1=0.6988 | Macro-F1=0.4428
#   Run 3/3 (seed=456)... Acc=0.6773 | Weighted-F1=0.6999 | Macro-F1=0.4433
#   >> RATA-RATA: Acc=0.6767 (±0.0007) | Weighted-F1=0.6992 (±0.0005) | Macro-F1=0.4429 (±0.0003)
#
# >> Dataset | SMOTE | Random Forest
#   Run 1/3 (seed=42)... Acc=0.7640 | Weighted-F1=0.7522 | Macro-F1=0.5054
#   Run 2/3 (seed=123)... Acc=0.7643 | Weighted-F1=0.7510 | Macro-F1=0.5033
#   Run 3/3 (seed=456)... Acc=0.7638 | Weighted-F1=0.7508 | Macro-F1=0.4961
#   >> RATA-RATA: Acc=0.7640 (±0.0002) | Weighted-F1=0.7513 (±0.0007) | Macro-F1=0.5016 (±0.0040)
#
# >> Dataset | SMOTE | Logistic Regression
#   Run 1/3 (seed=42)... Acc=0.6619 | Weighted-F1=0.6901 | Macro-F1=0.4425
#   Run 2/3 (seed=123)... Acc=0.6576 | Weighted-F1=0.6865 | Macro-F1=0.4360
#   Run 3/3 (seed=456)... Acc=0.6587 | Weighted-F1=0.6875 | Macro-F1=0.4388
#   >> RATA-RATA: Acc=0.6594 (±0.0018) | Weighted-F1=0.6880 (±0.0015) | Macro-F1=0.4391 (±0.0027)
#
# >> Dataset | RUS | MLP Baseline
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.4573 | Weighted-F1=0.5215 | Macro-F1=0.3349
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.4884 | Weighted-F1=0.5484 | Macro-F1=0.3495
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.4803 | Weighted-F1=0.5395 | Macro-F1=0.3535
#   >> RATA-RATA: Acc=0.4753 (±0.0131) | Weighted-F1=0.5365 (±0.0112) | Macro-F1=0.3460 (±0.0080)
#
# >> Dataset | RUS | MLP Advanced
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.7803 | Weighted-F1=0.6841 | Macro-F1=0.2922
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.1882 | Weighted-F1=0.0596 | Macro-F1=0.1056
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.0369 | Weighted-F1=0.0122 | Macro-F1=0.0387
#   >> RATA-RATA: Acc=0.3351 (±0.3208) | Weighted-F1=0.2520 (±0.3061) | Macro-F1=0.1455 (±0.1073)
#
# >> Dataset | RUS | MLP Keras Tuner
#   Run 1/3 (seed=42)...
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Acc=0.4252 | Weighted-F1=0.4862 | Macro-F1=0.3246
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 16s 76ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.2288 | Weighted-F1=0.3106 | Macro-F1=0.1529
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 15s 71ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.3034 | Weighted-F1=0.3135 | Macro-F1=0.2540
#   >> RATA-RATA: Acc=0.3191 (±0.0809) | Weighted-F1=0.3701 (±0.0821) | Macro-F1=0.2438 (±0.0705)
#
# >> Dataset | RUS | Naive Bayes
#   Run 1/3 (seed=42)... Acc=0.5498 | Weighted-F1=0.6060 | Macro-F1=0.3902
#   Run 2/3 (seed=123)... Acc=0.5735 | Weighted-F1=0.6262 | Macro-F1=0.4017
#   Run 3/3 (seed=456)... Acc=0.5408 | Weighted-F1=0.5979 | Macro-F1=0.3921
#   >> RATA-RATA: Acc=0.5547 (±0.0138) | Weighted-F1=0.6100 (±0.0119) | Macro-F1=0.3947 (±0.0051)
#
# >> Dataset | RUS | SVM
#   Run 1/3 (seed=42)... Acc=0.5079 | Weighted-F1=0.5739 | Macro-F1=0.3780
#   Run 2/3 (seed=123)... Acc=0.5208 | Weighted-F1=0.5866 | Macro-F1=0.3853
#   Run 3/3 (seed=456)... Acc=0.4914 | Weighted-F1=0.5583 | Macro-F1=0.3681
#   >> RATA-RATA: Acc=0.5067 (±0.0121) | Weighted-F1=0.5729 (±0.0116) | Macro-F1=0.3771 (±0.0071)
#
# >> Dataset | RUS | Random Forest
#   Run 1/3 (seed=42)... Acc=0.5275 | Weighted-F1=0.5937 | Macro-F1=0.3964
#   Run 2/3 (seed=123)... Acc=0.5185 | Weighted-F1=0.5865 | Macro-F1=0.3889
#   Run 3/3 (seed=456)... Acc=0.5071 | Weighted-F1=0.5752 | Macro-F1=0.3917
#   >> RATA-RATA: Acc=0.5177 (±0.0084) | Weighted-F1=0.5851 (±0.0076) | Macro-F1=0.3923 (±0.0031)
#
# >> Dataset | RUS | Logistic Regression
#   Run 1/3 (seed=42)... Acc=0.4902 | Weighted-F1=0.5556 | Macro-F1=0.3712
#   Run 2/3 (seed=123)... Acc=0.5096 | Weighted-F1=0.5742 | Macro-F1=0.3832
#   Run 3/3 (seed=456)... Acc=0.4888 | Weighted-F1=0.5534 | Macro-F1=0.3714
#   >> RATA-RATA: Acc=0.4962 (±0.0095) | Weighted-F1=0.5611 (±0.0093) | Macro-F1=0.3753 (±0.0056)
#
# >> Dataset | SMOTEENN | MLP Baseline
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.2767 | Weighted-F1=0.2652 | Macro-F1=0.2354
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.2741 | Weighted-F1=0.2557 | Macro-F1=0.2360
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.2704 | Weighted-F1=0.2555 | Macro-F1=0.2316
#   >> RATA-RATA: Acc=0.2737 (±0.0026) | Weighted-F1=0.2588 (±0.0045) | Macro-F1=0.2343 (±0.0020)
#
# >> Dataset | SMOTEENN | MLP Advanced
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.2487 | Weighted-F1=0.2114 | Macro-F1=0.2156
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.2577 | Weighted-F1=0.2304 | Macro-F1=0.2211
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.2601 | Weighted-F1=0.2312 | Macro-F1=0.2242
#   >> RATA-RATA: Acc=0.2555 (±0.0049) | Weighted-F1=0.2243 (±0.0092) | Macro-F1=0.2203 (±0.0036)
#
# >> Dataset | SMOTEENN | MLP Keras Tuner
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 16s 74ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.2450 | Weighted-F1=0.2108 | Macro-F1=0.2115
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 19s 89ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.2577 | Weighted-F1=0.2281 | Macro-F1=0.2222
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 21s 101ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.2660 | Weighted-F1=0.2586 | Macro-F1=0.2295
#   >> RATA-RATA: Acc=0.2562 (±0.0086) | Weighted-F1=0.2325 (±0.0198) | Macro-F1=0.2211 (±0.0074)
#
# >> Dataset | SMOTEENN | Naive Bayes
#   Run 1/3 (seed=42)... Acc=0.1894 | Weighted-F1=0.1072 | Macro-F1=0.1641
#   Run 2/3 (seed=123)... Acc=0.1928 | Weighted-F1=0.1106 | Macro-F1=0.1667
#   Run 3/3 (seed=456)... Acc=0.1915 | Weighted-F1=0.1081 | Macro-F1=0.1655
#   >> RATA-RATA: Acc=0.1912 (±0.0014) | Weighted-F1=0.1086 (±0.0014) | Macro-F1=0.1654 (±0.0011)
#
# >> Dataset | SMOTEENN | SVM
#   Run 1/3 (seed=42)... Acc=0.2487 | Weighted-F1=0.2243 | Macro-F1=0.2162
#   Run 2/3 (seed=123)... Acc=0.2464 | Weighted-F1=0.2196 | Macro-F1=0.2153
#   Run 3/3 (seed=456)... Acc=0.2488 | Weighted-F1=0.2255 | Macro-F1=0.2165
#   >> RATA-RATA: Acc=0.2480 (±0.0011) | Weighted-F1=0.2231 (±0.0026) | Macro-F1=0.2160 (±0.0005)
#
# >> Dataset | SMOTEENN | Random Forest
#   Run 1/3 (seed=42)... Acc=0.2375 | Weighted-F1=0.1751 | Macro-F1=0.2098
#   Run 2/3 (seed=123)... Acc=0.2344 | Weighted-F1=0.1692 | Macro-F1=0.2067
#   Run 3/3 (seed=456)... Acc=0.2347 | Weighted-F1=0.1714 | Macro-F1=0.2063
#   >> RATA-RATA: Acc=0.2355 (±0.0014) | Weighted-F1=0.1719 (±0.0024) | Macro-F1=0.2076 (±0.0016)
#
# >> Dataset | SMOTEENN | Logistic Regression
#   Run 1/3 (seed=42)... Acc=0.2105 | Weighted-F1=0.1610 | Macro-F1=0.1890
#   Run 2/3 (seed=123)... Acc=0.2084 | Weighted-F1=0.1567 | Macro-F1=0.1849
#   Run 3/3 (seed=456)... Acc=0.2101 | Weighted-F1=0.1601 | Macro-F1=0.1888
#   >> RATA-RATA: Acc=0.2097 (±0.0009) | Weighted-F1=0.1593 (±0.0019) | Macro-F1=0.1876 (±0.0019)
#
# >> Dataset | SMOTETomek | MLP Baseline
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.7653 | Weighted-F1=0.7246 | Macro-F1=0.4393
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.7660 | Weighted-F1=0.7231 | Macro-F1=0.4371
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.7659 | Weighted-F1=0.7276 | Macro-F1=0.4462
#   >> RATA-RATA: Acc=0.7658 (±0.0003) | Weighted-F1=0.7251 (±0.0019) | Macro-F1=0.4409 (±0.0039)
#
# >> Dataset | SMOTETomek | MLP Advanced
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.7439 | Weighted-F1=0.7253 | Macro-F1=0.4578
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Acc=0.7486 | Weighted-F1=0.7290 | Macro-F1=0.4618
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Acc=0.7415 | Weighted-F1=0.7278 | Macro-F1=0.4626
#   >> RATA-RATA: Acc=0.7447 (±0.0030) | Weighted-F1=0.7274 (±0.0015) | Macro-F1=0.4607 (±0.0021)
#
# >> Dataset | SMOTETomek | MLP Keras Tuner
#   Run 1/3 (seed=42)...
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# Acc=0.7237 | Weighted-F1=0.7126 | Macro-F1=0.4332
#   Run 2/3 (seed=123)...
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Acc=0.7267 | Weighted-F1=0.7170 | Macro-F1=0.4528
#   Run 3/3 (seed=456)...
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.7569 | Weighted-F1=0.7281 | Macro-F1=0.4490
#   >> RATA-RATA: Acc=0.7358 (±0.0150) | Weighted-F1=0.7192 (±0.0065) | Macro-F1=0.4450 (±0.0085)
#
# >> Dataset | SMOTETomek | Naive Bayes
#   Run 1/3 (seed=42)... Acc=0.6564 | Weighted-F1=0.6846 | Macro-F1=0.4472
#   Run 2/3 (seed=123)... Acc=0.6623 | Weighted-F1=0.6884 | Macro-F1=0.4534
#   Run 3/3 (seed=456)... Acc=0.6607 | Weighted-F1=0.6870 | Macro-F1=0.4504
#   >> RATA-RATA: Acc=0.6598 (±0.0025) | Weighted-F1=0.6867 (±0.0016) | Macro-F1=0.4503 (±0.0025)
#
# >> Dataset | SMOTETomek | SVM
#   Run 1/3 (seed=42)... Acc=0.6770 | Weighted-F1=0.6990 | Macro-F1=0.4429
#   Run 2/3 (seed=123)... Acc=0.6761 | Weighted-F1=0.6991 | Macro-F1=0.4412
#   Run 3/3 (seed=456)... Acc=0.6759 | Weighted-F1=0.6990 | Macro-F1=0.4426
#   >> RATA-RATA: Acc=0.6763 (±0.0005) | Weighted-F1=0.6990 (±0.0001) | Macro-F1=0.4422 (±0.0007)
#
# >> Dataset | SMOTETomek | Random Forest
#   Run 1/3 (seed=42)... Acc=0.7666 | Weighted-F1=0.7539 | Macro-F1=0.5055
#   Run 2/3 (seed=123)... Acc=0.7662 | Weighted-F1=0.7529 | Macro-F1=0.5066
#   Run 3/3 (seed=456)... Acc=0.7618 | Weighted-F1=0.7491 | Macro-F1=0.4942
#   >> RATA-RATA: Acc=0.7649 (±0.0022) | Weighted-F1=0.7520 (±0.0021) | Macro-F1=0.5021 (±0.0056)
#
# >> Dataset | SMOTETomek | Logistic Regression
#   Run 1/3 (seed=42)... Acc=0.6627 | Weighted-F1=0.6910 | Macro-F1=0.4432
#   Run 2/3 (seed=123)... Acc=0.6573 | Weighted-F1=0.6860 | Macro-F1=0.4358
#   Run 3/3 (seed=456)... Acc=0.6583 | Weighted-F1=0.6871 | Macro-F1=0.4394
#   >> RATA-RATA: Acc=0.6594 (±0.0024) | Weighted-F1=0.6880 (±0.0021) | Macro-F1=0.4395 (±0.0030)

# %%
import json
import numpy as np

# %%
def convert_results(obj):
    if isinstance(obj, dict):
        return {k: convert_results(v) for k,v in obj.items()}
    elif isinstance(obj, list):
        return [convert_results(i) for i in obj]
    elif isinstance(obj,(np.float32, np.float64)):
        return float(obj)
    elif isinstance(obj, (np.int32, np.int64)):
        return int(obj)
    return obj


all_results_fixed = {'Dataset_A': all_results}
with open('results/all_results.json','w') as f:
    json.dump(convert_results(all_results_fixed), f,indent=2)

#untuk load json
#with open('results/all_results.json', 'r') as f:
    #all_results =json.load(f)

# %%
from src.evaluation import print_all_metrics_table, find_best_model

# %%
# Langkah 1: Bungkus ulang variabel hasil running ke dalam dict baru
all_results_fixed = {'Dataset_A': all_results}

print("--- Menampilkan Tabel Metrik Berhasil ---")
# Langkah 2: Panggil tabel menggunakan variabel baru yang sudah dibungkus
print_all_metrics_table(all_results_fixed)

print("\n--- Mencari Model Terbaik ---")
# Langkah 3: Panggil fungsi pencari model terbaik dengan variabel baru yang benar
best_acc = find_best_model(all_results_fixed, metric='accuracy')
best_pre = find_best_model(all_results_fixed, metric='precision')
best_reca = find_best_model(all_results_fixed, metric='recall')
best_f1 = find_best_model(all_results_fixed, metric='f1')

# Langkah 4: Cetak hasilnya ke layar
print("Best Accuracy :", best_acc)
print("Best Precision:", best_pre)
print("Best Recall   :", best_reca)
print("Best F1-Score :", best_f1)
# Out:
# --- Menampilkan Tabel Metrik Berhasil ---
#
# ===============================================================================================
# RATA-RATA ACCURACY (3 RUNS) - Dataset_A
# ===============================================================================================
# Model                     No_Balancing             ROS           SMOTE             RUS        SMOTEENN      SMOTETomek
# ----------------------------------------------------------------------------------------------------------------------
# MLP Baseline            0.7116±0.0079  0.7481±0.0044  0.7696±0.0035  0.4753±0.0131  0.2737±0.0026  0.7658±0.0003
# MLP Advanced            0.7965±0.0009  0.7586±0.0038  0.7349±0.0092  0.3351±0.3208  0.2555±0.0049  0.7447±0.0030
# MLP Keras Tuner         0.7933±0.0002  0.7386±0.0194  0.7354±0.0032  0.3191±0.0809  0.2562±0.0086  0.7358±0.0150
# Naive Bayes             0.7916±0.0000  0.6511±0.0006  0.6614±0.0025  0.5547±0.0138  0.1912±0.0014  0.6598±0.0025
# SVM                     0.7956±0.0000  0.6172±0.0019  0.6767±0.0007  0.5067±0.0121  0.2480±0.0011  0.6763±0.0005
# Random Forest           0.7925±0.0008  0.7785±0.0010  0.7640±0.0002  0.5177±0.0084  0.2355±0.0014  0.7649±0.0022
# Logistic Regression     0.7968±0.0000  0.6110±0.0015  0.6594±0.0018  0.4962±0.0095  0.2097±0.0009  0.6594±0.0024
#
# ===============================================================================================
# RATA-RATA PRECISION (3 RUNS) - Dataset_A
# ===============================================================================================
# Model                     No_Balancing             ROS           SMOTE             RUS        SMOTEENN      SMOTETomek
# ----------------------------------------------------------------------------------------------------------------------
# MLP Baseline            0.7098±0.0031  0.7151±0.0014  0.7149±0.0050  0.6901±0.0030  0.6894±0.0043  0.7139±0.0020
# MLP Advanced            0.7690±0.0023  0.7181±0.0007  0.7123±0.0052  0.2465±0.2574  0.6943±0.0060  0.7161±0.0020
# MLP Keras Tuner         0.7636±0.0039  0.7165±0.0033  0.7126±0.0014  0.6933±0.0074  0.6925±0.0073  0.7110±0.0039
# Naive Bayes             0.7561±0.0000  0.7274±0.0008  0.7259±0.0004  0.7148±0.0031  0.7271±0.0042  0.7266±0.0005
# SVM                     0.7709±0.0000  0.7188±0.0001  0.7281±0.0008  0.7191±0.0031  0.7063±0.0011  0.7281±0.0006
# Random Forest           0.7634±0.0014  0.7528±0.0012  0.7431±0.0008  0.7335±0.0084  0.7057±0.0028  0.7437±0.0021
# Logistic Regression     0.7704±0.0000  0.7186±0.0017  0.7266±0.0012  0.7199±0.0034  0.7224±0.0010  0.7267±0.0019
#
# ===============================================================================================
# RATA-RATA RECALL (3 RUNS) - Dataset_A
# ===============================================================================================
# Model                     No_Balancing             ROS           SMOTE             RUS        SMOTEENN      SMOTETomek
# ----------------------------------------------------------------------------------------------------------------------
# MLP Baseline            0.7116±0.0079  0.7481±0.0044  0.7696±0.0035  0.4753±0.0131  0.2737±0.0026  0.7658±0.0003
# MLP Advanced            0.7965±0.0009  0.7586±0.0038  0.7349±0.0092  0.3351±0.3208  0.2555±0.0049  0.7447±0.0030
# MLP Keras Tuner         0.7933±0.0002  0.7386±0.0194  0.7354±0.0032  0.3191±0.0809  0.2562±0.0086  0.7358±0.0150
# Naive Bayes             0.7916±0.0000  0.6511±0.0006  0.6614±0.0025  0.5547±0.0138  0.1912±0.0014  0.6598±0.0025
# SVM                     0.7956±0.0000  0.6172±0.0019  0.6767±0.0007  0.5067±0.0121  0.2480±0.0011  0.6763±0.0005
# Random Forest           0.7925±0.0008  0.7785±0.0010  0.7640±0.0002  0.5177±0.0084  0.2355±0.0014  0.7649±0.0022
# Logistic Regression     0.7968±0.0000  0.6110±0.0015  0.6594±0.0018  0.4962±0.0095  0.2097±0.0009  0.6594±0.0024
#
# ===============================================================================================
# RATA-RATA F1 (3 RUNS) - Dataset_A
# ===============================================================================================
# Model                     No_Balancing             ROS           SMOTE             RUS        SMOTEENN      SMOTETomek
# ----------------------------------------------------------------------------------------------------------------------
# MLP Baseline            0.7083±0.0056  0.7274±0.0017  0.7235±0.0035  0.5365±0.0112  0.2588±0.0045  0.7251±0.0019
# MLP Advanced            0.7464±0.0037  0.7305±0.0003  0.7217±0.0066  0.2520±0.3061  0.2243±0.0092  0.7274±0.0015
# MLP Keras Tuner         0.7410±0.0071  0.7225±0.0076  0.7219±0.0018  0.3701±0.0821  0.2325±0.0198  0.7192±0.0065
# Naive Bayes             0.7396±0.0000  0.6808±0.0003  0.6874±0.0016  0.6100±0.0119  0.1086±0.0014  0.6867±0.0016
# SVM                     0.7423±0.0000  0.6542±0.0014  0.6992±0.0005  0.5729±0.0116  0.2231±0.0026  0.6990±0.0001
# Random Forest           0.7560±0.0011  0.7612±0.0011  0.7513±0.0007  0.5851±0.0076  0.1719±0.0024  0.7520±0.0021
# Logistic Regression     0.7503±0.0000  0.6507±0.0014  0.6880±0.0015  0.5611±0.0093  0.1593±0.0019  0.6880±0.0021
#
# --- Mencari Model Terbaik ---
#
# Dataset_A - Best accuracy:
#   Model    : Logistic Regression
#   Balancing: No_Balancing
#   Score    : 0.7968 ± 0.0000
#
# Dataset_A - Best precision:
#   Model    : SVM
#   Balancing: No_Balancing
#   Score    : 0.7709 ± 0.0000
#
# Dataset_A - Best recall:
#   Model    : Logistic Regression
#   Balancing: No_Balancing
#   Score    : 0.7968 ± 0.0000
#
# Dataset_A - Best f1:
#   Model    : Random Forest
#   Balancing: ROS
#   Score    : 0.7612 ± 0.0011
# Best Accuracy : {'Dataset_A': {'dataset': 'Dataset_A', 'balancing': 'No_Balancing', 'model': 'Logistic Regression', 'score_mean': np.float64(0.796770044304702), 'score_std': np.float64(0.0)}}
# Best Precision: {'Dataset_A': {'dataset': 'Dataset_A', 'balancing': 'No_Balancing', 'model': 'SVM', 'score_mean': np.float64(0.770883180288288), 'score_std': np.float64(0.0)}}
# Best Recall   : {'Dataset_A': {'dataset': 'Dataset_A', 'balancing': 'No_Balancing', 'model': 'Logistic Regression', 'score_mean': np.float64(0.796770044304702), 'score_std': np.float64(0.0)}}
# Best F1-Score : {'Dataset_A': {'dataset': 'Dataset_A', 'balancing': 'ROS', 'model': 'Random Forest', 'score_mean': np.float64(0.7612450332422037), 'score_std': np.float64(0.001097449305626085)}}

# %%
import json

# Mengamankan hasil running 18 jam ke dalam file harddisk
with open('results/all_results.json', 'w') as f:
    json.dump(convert_results(all_results_fixed), f, indent=2)

# %%
print_all_metrics_table(all_results)
best_acc = find_best_model(all_results, metric='accuracy')
best_pre = find_best_model(all_results, metric='precision')
best_reca = find_best_model(all_results, metric='recall')
best_f1 = find_best_model(all_results, metric='f1')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 print_all_metrics_table(all_results)
# ----> 2 best_acc = find_best_model(all_results, metric='accuracy')
#       3 best_pre = find_best_model(all_results, metric='precision')
#       4 best_reca = find_best_model(all_results, metric='recall')
#
# File ~\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\src\evaluation.py:234, in find_best_model(all_results, metric)
#     232 for bal_name in all_results[ds_name]:
#     233     for model_name in all_results[ds_name][bal_name]:
# --> 234         score = all_results[ds_name][bal_name][model_name][metric]['mean']
#     235         if score > best_score:
#     236             best_score = score
#
# KeyError: 'accuracy'

# %%
# EValuasi

import os, gc
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import backend as K
import keras_tuner as kt

from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN,SMOTETomek

from src.models import (
    create_mlp_baseline, create_mlp_advance, make_tuner_builder,create_naive_bayes, create_logistic_regression, create_random_forest, create_svm, get_callbacks, MODEL_CONFIGS
)

from src.balancing import BALANCING_METHODS
from src.evaluation import (
    plot_confusion_matrix,
    plot_roc_curve,
    plot_learning_curve,
    print_all_metrics_table,
    print_classification_report,
    find_best_model
)

SEED=42

# %%
def prepare(df, kx, ky):
    X_tr, X_te, y_tr, y_te = train_test_split(df[kx], df[ky], test_size=0.2, random_state=SEED)

    tfidf = TfidfVectorizer(max_features=5000, min_df=2, max_df=0.95, ngram_range=(1,2))

    return tfidf.fit_transform(X_tr), tfidf.transform(X_te), to_categorical(y_tr,3), to_categorical(y_te,3)

data_prepared = {
    'Dataset_A': prepare(df_kesepakatan, 'clean_text', 'label'),
    #'Dataset_B': prepare(df_fadly, 'clean_text', 'label'),
}

# %%
DATASET_FOLDERS = {'Dataset_A': 'dataset_kesepakatan'}
total = len(data_prepared) * len(BALANCING_METHODS) * len(MODEL_CONFIGS)
counter = 0

for ds_name, (X_train, X_test, y_train_oh, y_test_oh) in data_prepared.items():
    y_true = np.argmax(y_test_oh, axis=1)

    for model_name, model_type in MODEL_CONFIGS.items():
        save_dir = f'results/{DATASET_FOLDERS[ds_name]}/{model_name.replace(" ","_")}'
        os.makedirs(save_dir, exist_ok=True)

        for bal_name, bal_class in BALANCING_METHODS.items():
            counter += 1
            tag = f'{model_name} + {bal_name} ({ds_name})'
            print(f"\n[{counter}/{total}] {tag}")

            # --- Balancing ---
            sampler = bal_class(random_state=SEED)
            X_bal, y_bal = sampler.fit_resample(X_train, y_train_oh)

            history = None
            y_pred_prob = None

            # --- Train ---
            if model_type == 'mlp_baseline':
                model = create_mlp_baseline(X_bal.shape[1])
                history = model.fit(X_bal, y_bal, epochs=50, batch_size=32,
                                    validation_split=0.15, callbacks=get_callbacks(), verbose=0)
                y_pred_prob = model.predict(X_test)
                y_pred = np.argmax(y_pred_prob, axis=1)
                del model; gc.collect(); K.clear_session()

            elif model_type == 'mlp_advance':
                model = create_mlp_advance(X_bal.shape[1])
                history = model.fit(X_bal, y_bal, epochs=50, batch_size=32,
                                    validation_split=0.15, callbacks=get_callbacks(), verbose=0)
                y_pred_prob = model.predict(X_test)
                y_pred = np.argmax(y_pred_prob, axis=1)
                del model; gc.collect(); K.clear_session()

            elif model_type == 'mlp_tuner':
                builder = make_tuner_builder(X_bal.shape[1])
                tuner = kt.RandomSearch(
                    builder, objective='val_accuracy', max_trials=5,
                    executions_per_trial=1,
                    directory=f'tuner_viz_{bal_name}_{ds_name}',
                    project_name='viz', overwrite=True
                )
                tuner.search(X_bal, y_bal, epochs=50, batch_size=32,
                             validation_split=0.15, callbacks=get_callbacks(), verbose=0)
                best_model = tuner.get_best_models(1)[0]
                y_pred_prob = best_model.predict(X_test)
                y_pred = np.argmax(y_pred_prob, axis=1)
                del best_model, tuner; gc.collect(); K.clear_session()

            else:  # sklearn
                y_bal_1d = np.argmax(y_bal, axis=1)
                if model_type == 'naive_bayes':
                    mdl = create_naive_bayes()
                elif model_type == 'svm':
                    mdl = create_svm(random_state=SEED)
                elif model_type == 'random_forest':
                    mdl = create_random_forest(random_state=SEED)
                elif model_type == 'logistic_regression':
                    mdl = create_logistic_regression(random_state=SEED)
                mdl.fit(X_bal, y_bal_1d)
                y_pred = mdl.predict(X_test)
                y_pred_prob = mdl.predict_proba(X_test)

            # --- Panggil fungsi evaluation.py ---
            prefix = f'{save_dir}/{bal_name}'

            print_classification_report(y_true, y_pred, title=tag)

            plot_confusion_matrix(y_true, y_pred, tag,
                                  save_path=f'{prefix}_cm.png')

            if y_pred_prob is not None:
                plot_roc_curve(y_true, y_pred_prob, tag,
                               save_path=f'{prefix}_roc.png')

            if history is not None:
                plot_learning_curve(history, tag,
                                    save_path=f'{prefix}_learning.png')

            print(f"  Acc={accuracy_score(y_true, y_pred):.4f} | F1={f1_score(y_true, y_pred, average='weighted'):.4f}")

print("\nSelesai!")
# Out:
# [1/42] MLP Baseline + No_Balancing (Dataset_A)
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# --- Classification Report: MLP Baseline + No_Balancing (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.81      0.97      0.88      5460
#       Netral       0.62      0.19      0.29      1317
#      Positif       0.86      0.14      0.24       220
#
#     accuracy                           0.80      6997
#    macro avg       0.76      0.44      0.47      6997
# weighted avg       0.78      0.80      0.75      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Baseline/No_Balancing_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/No_Balancing_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/No_Balancing_learning.png
#   Acc=0.7991 | F1=0.7526
#
# [2/42] MLP Baseline + ROS (Dataset_A)
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# --- Classification Report: MLP Baseline + ROS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.81      0.89      0.85      5460
#       Netral       0.40      0.25      0.31      1317
#      Positif       0.22      0.20      0.21       220
#
#     accuracy                           0.75      6997
#    macro avg       0.48      0.45      0.46      6997
# weighted avg       0.72      0.75      0.73      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Baseline/ROS_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/ROS_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/ROS_learning.png
#   Acc=0.7495 | F1=0.7291
#
# [3/42] MLP Baseline + SMOTE (Dataset_A)
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# --- Classification Report: MLP Baseline + SMOTE (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.81      0.91      0.86      5460
#       Netral       0.39      0.21      0.27      1317
#      Positif       0.31      0.17      0.22       220
#
#     accuracy                           0.76      6997
#    macro avg       0.50      0.43      0.45      6997
# weighted avg       0.71      0.76      0.73      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTE_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTE_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTE_learning.png
#   Acc=0.7573 | F1=0.7270
#
# [4/42] MLP Baseline + RUS (Dataset_A)
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# --- Classification Report: MLP Baseline + RUS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.85      0.52      0.65      5460
#       Netral       0.26      0.56      0.36      1317
#      Positif       0.10      0.36      0.15       220
#
#     accuracy                           0.52      6997
#    macro avg       0.40      0.48      0.38      6997
# weighted avg       0.71      0.52      0.58      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Baseline/RUS_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/RUS_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/RUS_learning.png
#   Acc=0.5232 | F1=0.5756
#
# [5/42] MLP Baseline + SMOTEENN (Dataset_A)
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# --- Classification Report: MLP Baseline + SMOTEENN (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.84      0.15      0.26      5460
#       Netral       0.20      0.79      0.32      1317
#      Positif       0.08      0.31      0.12       220
#
#     accuracy                           0.28      6997
#    macro avg       0.37      0.42      0.24      6997
# weighted avg       0.70      0.28      0.27      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTEENN_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTEENN_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTEENN_learning.png
#   Acc=0.2783 | F1=0.2683
#
# [6/42] MLP Baseline + SMOTETomek (Dataset_A)
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# --- Classification Report: MLP Baseline + SMOTETomek (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.81      0.93      0.86      5460
#       Netral       0.43      0.18      0.26      1317
#      Positif       0.33      0.17      0.22       220
#
#     accuracy                           0.77      6997
#    macro avg       0.52      0.43      0.45      6997
# weighted avg       0.72      0.77      0.73      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTETomek_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTETomek_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTETomek_learning.png
#   Acc=0.7676 | F1=0.7296
#
# [7/42] MLP Advanced + No_Balancing (Dataset_A)
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Classification Report: MLP Advanced + No_Balancing (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.80      0.97      0.88      5460
#       Netral       0.61      0.16      0.25      1317
#      Positif       0.63      0.15      0.25       220
#
#     accuracy                           0.79      6997
#    macro avg       0.68      0.43      0.46      6997
# weighted avg       0.76      0.79      0.74      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Advanced/No_Balancing_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/No_Balancing_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/No_Balancing_learning.png
#   Acc=0.7941 | F1=0.7425
#
# [8/42] MLP Advanced + ROS (Dataset_A)
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# --- Classification Report: MLP Advanced + ROS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.81      0.92      0.86      5460
#       Netral       0.43      0.22      0.30      1317
#      Positif       0.30      0.18      0.22       220
#
#     accuracy                           0.76      6997
#    macro avg       0.51      0.44      0.46      6997
# weighted avg       0.72      0.76      0.73      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Advanced/ROS_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/ROS_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/ROS_learning.png
#   Acc=0.7636 | F1=0.7342
#
# [9/42] MLP Advanced + SMOTE (Dataset_A)
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# --- Classification Report: MLP Advanced + SMOTE (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.82      0.87      0.84      5460
#       Netral       0.37      0.28      0.32      1317
#      Positif       0.23      0.20      0.21       220
#
#     accuracy                           0.74      6997
#    macro avg       0.47      0.45      0.46      6997
# weighted avg       0.71      0.74      0.72      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTE_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTE_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTE_learning.png
#   Acc=0.7362 | F1=0.7234
#
# [10/42] MLP Advanced + RUS (Dataset_A)
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# --- Classification Report: MLP Advanced + RUS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.00      0.00      0.00      5460
#       Netral       0.19      1.00      0.32      1317
#      Positif       0.00      0.00      0.00       220
#
#     accuracy                           0.19      6997
#    macro avg       0.06      0.33      0.11      6997
# weighted avg       0.04      0.19      0.06      6997
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#   Saved: results/dataset_kesepakatan/MLP_Advanced/RUS_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/RUS_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/RUS_learning.png
#   Acc=0.1882 | F1=0.0596
#
# [11/42] MLP Advanced + SMOTEENN (Dataset_A)
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Classification Report: MLP Advanced + SMOTEENN (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.84      0.11      0.20      5460
#       Netral       0.20      0.82      0.32      1317
#      Positif       0.08      0.35      0.13       220
#
#     accuracy                           0.25      6997
#    macro avg       0.38      0.43      0.22      6997
# weighted avg       0.70      0.25      0.22      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTEENN_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTEENN_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTEENN_learning.png
#   Acc=0.2531 | F1=0.2206
#
# [12/42] MLP Advanced + SMOTETomek (Dataset_A)
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Classification Report: MLP Advanced + SMOTETomek (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.82      0.89      0.85      5460
#       Netral       0.39      0.26      0.31      1317
#      Positif       0.30      0.20      0.24       220
#
#     accuracy                           0.75      6997
#    macro avg       0.50      0.45      0.47      6997
# weighted avg       0.72      0.75      0.73      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTETomek_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTETomek_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTETomek_learning.png
#   Acc=0.7502 | F1=0.7308
#
# [13/42] MLP Keras Tuner + No_Balancing (Dataset_A)
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 13s 64ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# --- Classification Report: MLP Keras Tuner + No_Balancing (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.81      0.96      0.88      5460
#       Netral       0.56      0.20      0.30      1317
#      Positif       0.77      0.16      0.27       220
#
#     accuracy                           0.79      6997
#    macro avg       0.71      0.44      0.48      6997
# weighted avg       0.76      0.79      0.75      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/No_Balancing_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/No_Balancing_roc.png
#   Acc=0.7938 | F1=0.7516
#
# [14/42] MLP Keras Tuner + ROS (Dataset_A)
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# --- Classification Report: MLP Keras Tuner + ROS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.80      0.95      0.87      5460
#       Netral       0.44      0.12      0.19      1317
#      Positif       0.27      0.19      0.22       220
#
#     accuracy                           0.77      6997
#    macro avg       0.50      0.42      0.43      6997
# weighted avg       0.71      0.77      0.72      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/ROS_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/ROS_roc.png
#   Acc=0.7690 | F1=0.7197
#
# [15/42] MLP Keras Tuner + SMOTE (Dataset_A)
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 20s 94ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Classification Report: MLP Keras Tuner + SMOTE (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.82      0.83      0.82      5460
#       Netral       0.35      0.30      0.33      1317
#      Positif       0.14      0.23      0.18       220
#
#     accuracy                           0.71      6997
#    macro avg       0.44      0.45      0.44      6997
# weighted avg       0.71      0.71      0.71      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/SMOTE_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/SMOTE_roc.png
#   Acc=0.7094 | F1=0.7098
#
# [16/42] MLP Keras Tuner + RUS (Dataset_A)
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 17s 80ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# --- Classification Report: MLP Keras Tuner + RUS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.82      0.48      0.61      5460
#       Netral       0.25      0.50      0.33      1317
#      Positif       0.06      0.31      0.10       220
#
#     accuracy                           0.48      6997
#    macro avg       0.38      0.43      0.35      6997
# weighted avg       0.69      0.48      0.54      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/RUS_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/RUS_roc.png
#   Acc=0.4826 | F1=0.5415
#
# [17/42] MLP Keras Tuner + SMOTEENN (Dataset_A)
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Classification Report: MLP Keras Tuner + SMOTEENN (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.85      0.10      0.19      5460
#       Netral       0.20      0.74      0.32      1317
#      Positif       0.06      0.40      0.10       220
#
#     accuracy                           0.23      6997
#    macro avg       0.37      0.42      0.20      6997
# weighted avg       0.71      0.23      0.21      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/SMOTEENN_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/SMOTEENN_roc.png
#   Acc=0.2341 | F1=0.2085
#
# [18/42] MLP Keras Tuner + SMOTETomek (Dataset_A)
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Classification Report: MLP Keras Tuner + SMOTETomek (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.82      0.85      0.83      5460
#       Netral       0.35      0.30      0.32      1317
#      Positif       0.20      0.22      0.21       220
#
#     accuracy                           0.72      6997
#    macro avg       0.46      0.45      0.45      6997
# weighted avg       0.71      0.72      0.72      6997
#
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/SMOTETomek_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/SMOTETomek_roc.png
#   Acc=0.7226 | F1=0.7162
#
# [19/42] Naive Bayes + No_Balancing (Dataset_A)
#
# --- Classification Report: Naive Bayes + No_Balancing (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.80      0.97      0.88      5460
#       Netral       0.59      0.15      0.24      1317
#      Positif       0.55      0.15      0.24       220
#
#     accuracy                           0.79      6997
#    macro avg       0.65      0.42      0.45      6997
# weighted avg       0.76      0.79      0.74      6997
#
#   Saved: results/dataset_kesepakatan/Naive_Bayes/No_Balancing_cm.png
#   Saved: results/dataset_kesepakatan/Naive_Bayes/No_Balancing_roc.png
#   Acc=0.7916 | F1=0.7396
#
# [20/42] Naive Bayes + ROS (Dataset_A)
#
# --- Classification Report: Naive Bayes + ROS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.85      0.71      0.77      5460
#       Netral       0.33      0.47      0.39      1317
#      Positif       0.13      0.34      0.18       220
#
#     accuracy                           0.65      6997
#    macro avg       0.44      0.50      0.45      6997
# weighted avg       0.73      0.65      0.68      6997
#
#   Saved: results/dataset_kesepakatan/Naive_Bayes/ROS_cm.png
#   Saved: results/dataset_kesepakatan/Naive_Bayes/ROS_roc.png
#   Acc=0.6511 | F1=0.6810
#
# [21/42] Naive Bayes + SMOTE (Dataset_A)
#
# --- Classification Report: Naive Bayes + SMOTE (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.84      0.72      0.78      5460
#       Netral       0.34      0.45      0.39      1317
#      Positif       0.13      0.33      0.18       220
#
#     accuracy                           0.66      6997
#    macro avg       0.44      0.50      0.45      6997
# weighted avg       0.73      0.66      0.69      6997
#
#   Saved: results/dataset_kesepakatan/Naive_Bayes/SMOTE_cm.png
#   Saved: results/dataset_kesepakatan/Naive_Bayes/SMOTE_roc.png
#   Acc=0.6583 | F1=0.6855
#
# [22/42] Naive Bayes + RUS (Dataset_A)
#
# --- Classification Report: Naive Bayes + RUS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.83      0.58      0.69      5460
#       Netral       0.30      0.44      0.36      1317
#      Positif       0.08      0.44      0.13       220
#
#     accuracy                           0.55      6997
#    macro avg       0.40      0.49      0.39      6997
# weighted avg       0.71      0.55      0.61      6997
#
#   Saved: results/dataset_kesepakatan/Naive_Bayes/RUS_cm.png
#   Saved: results/dataset_kesepakatan/Naive_Bayes/RUS_roc.png
#   Acc=0.5498 | F1=0.6060
#
# [23/42] Naive Bayes + SMOTEENN (Dataset_A)
#
# --- Classification Report: Naive Bayes + SMOTEENN (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.87      0.03      0.06      5460
#       Netral       0.20      0.82      0.32      1317
#      Positif       0.07      0.43      0.12       220
#
#     accuracy                           0.19      6997
#    macro avg       0.38      0.43      0.16      6997
# weighted avg       0.72      0.19      0.11      6997
#
#   Saved: results/dataset_kesepakatan/Naive_Bayes/SMOTEENN_cm.png
#   Saved: results/dataset_kesepakatan/Naive_Bayes/SMOTEENN_roc.png
#   Acc=0.1895 | F1=0.1073
#
# [24/42] Naive Bayes + SMOTETomek (Dataset_A)
#
# --- Classification Report: Naive Bayes + SMOTETomek (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.84      0.72      0.78      5460
#       Netral       0.34      0.45      0.39      1317
#      Positif       0.12      0.33      0.18       220
#
#     accuracy                           0.66      6997
#    macro avg       0.44      0.50      0.45      6997
# weighted avg       0.73      0.66      0.68      6997
#
#   Saved: results/dataset_kesepakatan/Naive_Bayes/SMOTETomek_cm.png
#   Saved: results/dataset_kesepakatan/Naive_Bayes/SMOTETomek_roc.png
#   Acc=0.6566 | F1=0.6846
#
# [25/42] SVM + No_Balancing (Dataset_A)
#
# --- Classification Report: SVM + No_Balancing (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.80      0.98      0.88      5460
#       Netral       0.62      0.16      0.25      1317
#      Positif       0.85      0.13      0.23       220
#
#     accuracy                           0.80      6997
#    macro avg       0.76      0.42      0.45      6997
# weighted avg       0.77      0.80      0.74      6997
#
#   Saved: results/dataset_kesepakatan/SVM/No_Balancing_cm.png
#   Saved: results/dataset_kesepakatan/SVM/No_Balancing_roc.png
#   Acc=0.7956 | F1=0.7423
#
# [26/42] SVM + ROS (Dataset_A)
#
# --- Classification Report: SVM + ROS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.84      0.66      0.74      5460
#       Netral       0.31      0.48      0.38      1317
#      Positif       0.11      0.31      0.16       220
#
#     accuracy                           0.62      6997
#    macro avg       0.42      0.49      0.43      6997
# weighted avg       0.72      0.62      0.66      6997
#
#   Saved: results/dataset_kesepakatan/SVM/ROS_cm.png
#   Saved: results/dataset_kesepakatan/SVM/ROS_roc.png
#   Acc=0.6193 | F1=0.6557
#
# [27/42] SVM + SMOTE (Dataset_A)
#
# --- Classification Report: SVM + SMOTE (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.84      0.76      0.80      5460
#       Netral       0.38      0.38      0.38      1317
#      Positif       0.10      0.32      0.15       220
#
#     accuracy                           0.68      6997
#    macro avg       0.44      0.49      0.44      6997
# weighted avg       0.73      0.68      0.70      6997
#
#   Saved: results/dataset_kesepakatan/SVM/SMOTE_cm.png
#   Saved: results/dataset_kesepakatan/SVM/SMOTE_roc.png
#   Acc=0.6771 | F1=0.6990
#
# [28/42] SVM + RUS (Dataset_A)
#
# --- Classification Report: SVM + RUS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.84      0.52      0.64      5460
#       Netral       0.31      0.47      0.37      1317
#      Positif       0.07      0.51      0.12       220
#
#     accuracy                           0.51      6997
#    macro avg       0.41      0.50      0.38      6997
# weighted avg       0.72      0.51      0.57      6997
#
#   Saved: results/dataset_kesepakatan/SVM/RUS_cm.png
#   Saved: results/dataset_kesepakatan/SVM/RUS_roc.png
#   Acc=0.5079 | F1=0.5739
#
# [29/42] SVM + SMOTEENN (Dataset_A)
#
# --- Classification Report: SVM + SMOTEENN (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.85      0.12      0.20      5460
#       Netral       0.21      0.77      0.33      1317
#      Positif       0.07      0.43      0.11       220
#
#     accuracy                           0.25      6997
#    macro avg       0.38      0.44      0.22      6997
# weighted avg       0.71      0.25      0.22      6997
#
#   Saved: results/dataset_kesepakatan/SVM/SMOTEENN_cm.png
#   Saved: results/dataset_kesepakatan/SVM/SMOTEENN_roc.png
#   Acc=0.2487 | F1=0.2243
#
# [30/42] SVM + SMOTETomek (Dataset_A)
#
# --- Classification Report: SVM + SMOTETomek (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.84      0.76      0.80      5460
#       Netral       0.38      0.37      0.38      1317
#      Positif       0.10      0.32      0.15       220
#
#     accuracy                           0.68      6997
#    macro avg       0.44      0.49      0.44      6997
# weighted avg       0.73      0.68      0.70      6997
#
#   Saved: results/dataset_kesepakatan/SVM/SMOTETomek_cm.png
#   Saved: results/dataset_kesepakatan/SVM/SMOTETomek_roc.png
#   Acc=0.6770 | F1=0.6990
#
# [31/42] Random Forest + No_Balancing (Dataset_A)
#
# --- Classification Report: Random Forest + No_Balancing (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.81      0.95      0.88      5460
#       Netral       0.54      0.24      0.33      1317
#      Positif       0.80      0.15      0.25       220
#
#     accuracy                           0.79      6997
#    macro avg       0.72      0.44      0.48      6997
# weighted avg       0.76      0.79      0.75      6997
#
#   Saved: results/dataset_kesepakatan/Random_Forest/No_Balancing_cm.png
#   Saved: results/dataset_kesepakatan/Random_Forest/No_Balancing_roc.png
#   Acc=0.7915 | F1=0.7544
#
# [32/42] Random Forest + ROS (Dataset_A)
#
# --- Classification Report: Random Forest + ROS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.83      0.91      0.87      5460
#       Netral       0.50      0.35      0.41      1317
#      Positif       0.33      0.20      0.25       220
#
#     accuracy                           0.78      6997
#    macro avg       0.55      0.49      0.51      6997
# weighted avg       0.75      0.78      0.76      6997
#
#   Saved: results/dataset_kesepakatan/Random_Forest/ROS_cm.png
#   Saved: results/dataset_kesepakatan/Random_Forest/ROS_roc.png
#   Acc=0.7798 | F1=0.7628
#
# [33/42] Random Forest + SMOTE (Dataset_A)
#
# --- Classification Report: Random Forest + SMOTE (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.83      0.88      0.86      5460
#       Netral       0.45      0.35      0.40      1317
#      Positif       0.31      0.23      0.26       220
#
#     accuracy                           0.76      6997
#    macro avg       0.53      0.49      0.51      6997
# weighted avg       0.74      0.76      0.75      6997
#
#   Saved: results/dataset_kesepakatan/Random_Forest/SMOTE_cm.png
#   Saved: results/dataset_kesepakatan/Random_Forest/SMOTE_roc.png
#   Acc=0.7640 | F1=0.7522
#
# [34/42] Random Forest + RUS (Dataset_A)
#
# --- Classification Report: Random Forest + RUS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.86      0.53      0.66      5460
#       Netral       0.33      0.49      0.40      1317
#      Positif       0.08      0.57      0.13       220
#
#     accuracy                           0.53      6997
#    macro avg       0.42      0.53      0.40      6997
# weighted avg       0.74      0.53      0.59      6997
#
#   Saved: results/dataset_kesepakatan/Random_Forest/RUS_cm.png
#   Saved: results/dataset_kesepakatan/Random_Forest/RUS_roc.png
#   Acc=0.5275 | F1=0.5937
#
# [35/42] Random Forest + SMOTEENN (Dataset_A)
#
# --- Classification Report: Random Forest + SMOTEENN (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.85      0.08      0.14      5460
#       Netral       0.20      0.90      0.33      1317
#      Positif       0.11      0.32      0.16       220
#
#     accuracy                           0.24      6997
#    macro avg       0.39      0.43      0.21      6997
# weighted avg       0.70      0.24      0.18      6997
#
#   Saved: results/dataset_kesepakatan/Random_Forest/SMOTEENN_cm.png
#   Saved: results/dataset_kesepakatan/Random_Forest/SMOTEENN_roc.png
#   Acc=0.2375 | F1=0.1751
#
# [36/42] Random Forest + SMOTETomek (Dataset_A)
#
# --- Classification Report: Random Forest + SMOTETomek (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.83      0.89      0.86      5460
#       Netral       0.46      0.36      0.40      1317
#      Positif       0.31      0.22      0.26       220
#
#     accuracy                           0.77      6997
#    macro avg       0.53      0.49      0.51      6997
# weighted avg       0.75      0.77      0.75      6997
#
#   Saved: results/dataset_kesepakatan/Random_Forest/SMOTETomek_cm.png
#   Saved: results/dataset_kesepakatan/Random_Forest/SMOTETomek_roc.png
#   Acc=0.7666 | F1=0.7539
#
# [37/42] Logistic Regression + No_Balancing (Dataset_A)
#
# --- Classification Report: Logistic Regression + No_Balancing (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.81      0.97      0.88      5460
#       Netral       0.59      0.19      0.29      1317
#      Positif       0.87      0.15      0.26       220
#
#     accuracy                           0.80      6997
#    macro avg       0.76      0.44      0.47      6997
# weighted avg       0.77      0.80      0.75      6997
#
#   Saved: results/dataset_kesepakatan/Logistic_Regression/No_Balancing_cm.png
#   Saved: results/dataset_kesepakatan/Logistic_Regression/No_Balancing_roc.png
#   Acc=0.7968 | F1=0.7503
#
# [38/42] Logistic Regression + ROS (Dataset_A)
#
# --- Classification Report: Logistic Regression + ROS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.84      0.66      0.74      5460
#       Netral       0.31      0.46      0.37      1317
#      Positif       0.10      0.34      0.15       220
#
#     accuracy                           0.61      6997
#    macro avg       0.42      0.49      0.42      6997
# weighted avg       0.72      0.61      0.65      6997
#
#   Saved: results/dataset_kesepakatan/Logistic_Regression/ROS_cm.png
#   Saved: results/dataset_kesepakatan/Logistic_Regression/ROS_roc.png
#   Acc=0.6108 | F1=0.6503
#
# [39/42] Logistic Regression + SMOTE (Dataset_A)
#
# --- Classification Report: Logistic Regression + SMOTE (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.84      0.74      0.79      5460
#       Netral       0.37      0.40      0.38      1317
#      Positif       0.10      0.36      0.16       220
#
#     accuracy                           0.66      6997
#    macro avg       0.44      0.50      0.44      6997
# weighted avg       0.73      0.66      0.69      6997
#
#   Saved: results/dataset_kesepakatan/Logistic_Regression/SMOTE_cm.png
#   Saved: results/dataset_kesepakatan/Logistic_Regression/SMOTE_roc.png
#   Acc=0.6619 | F1=0.6901
#
# [40/42] Logistic Regression + RUS (Dataset_A)
#
# --- Classification Report: Logistic Regression + RUS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.84      0.49      0.62      5460
#       Netral       0.29      0.49      0.37      1317
#      Positif       0.07      0.54      0.13       220
#
#     accuracy                           0.49      6997
#    macro avg       0.40      0.51      0.37      6997
# weighted avg       0.72      0.49      0.56      6997
#
#   Saved: results/dataset_kesepakatan/Logistic_Regression/RUS_cm.png
#   Saved: results/dataset_kesepakatan/Logistic_Regression/RUS_roc.png
#   Acc=0.4902 | F1=0.5556
#
# [41/42] Logistic Regression + SMOTEENN (Dataset_A)
#
# --- Classification Report: Logistic Regression + SMOTEENN (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.87      0.06      0.12      5460
#       Netral       0.22      0.76      0.34      1317
#      Positif       0.06      0.55      0.11       220
#
#     accuracy                           0.21      6997
#    macro avg       0.38      0.46      0.19      6997
# weighted avg       0.72      0.21      0.16      6997
#
#   Saved: results/dataset_kesepakatan/Logistic_Regression/SMOTEENN_cm.png
#   Saved: results/dataset_kesepakatan/Logistic_Regression/SMOTEENN_roc.png
#   Acc=0.2105 | F1=0.1610
#
# [42/42] Logistic Regression + SMOTETomek (Dataset_A)
#
# --- Classification Report: Logistic Regression + SMOTETomek (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.84      0.74      0.79      5460
#       Netral       0.37      0.40      0.39      1317
#      Positif       0.10      0.36      0.16       220
#
#     accuracy                           0.66      6997
#    macro avg       0.44      0.50      0.44      6997
# weighted avg       0.73      0.66      0.69      6997
#
#   Saved: results/dataset_kesepakatan/Logistic_Regression/SMOTETomek_cm.png
#   Saved: results/dataset_kesepakatan/Logistic_Regression/SMOTETomek_roc.png
#   Acc=0.6627 | F1=0.6910
#
# Selesai!
