# %%
import pandas as pd
from src.balancing import run_experiments_single_dataset #run_all_experiments

# %%
#df_rendika = pd.read_csv('data/processed/preprocessed_dataset_rendika.csv')
#df_fadly = pd.read_csv('data/processed/preprocessed_dataset_fadly.csv')

# =================================================================
# STEP 1: LOAD DATA & PENYESUAIAN KOLOM LABEL (WAJIB JALANKAN INI)
# =================================================================

# 1. Pastikan variabel df_kesepakatan membaca file merge yang baru
df_kesepakatan = pd.read_csv('data_merge_rendika_fadly.csv')

# 2. Buat kolom 'label' baru menggunakan nilai dari label_rendika_x atau label_rendika_y
# Kita pakai label_rendika_x sebagai acuan utama
df_kesepakatan['label'] = df_kesepakatan['label_rendika_x']

# 3. WAJIB ubah tipe data menjadi integer biar Keras / TensorFlow tidak error!
df_kesepakatan['label'] = df_kesepakatan['label'].astype(int)

# 4. Intip data sebentar untuk memastikan kolom 'label' sudah tercipta dengan benar
print("Kolom DataFrame kamu sekarang:", df_kesepakatan.columns.tolist())
print(df_kesepakatan[['clean_text', 'label']].head())
# Out:
# Kolom DataFrame kamu sekarang: ['clean_text', 'label_rendika_x', 'label_rendika_y', 'label']
#                                           clean_text  label
# 0  nyata bestienya koruptor kakap pertamina riva ...      0
# 1  salah satu lebih pertamax oplos rubah suara kn...      0
# 2                                           juga win      1
# 3  td pagi buka tiktok yang lucu sekarang konoha ...      0
# 4              herman khaeron amplop pertamina oplos      0

# %%
import marimo as mo

# %% [markdown]
# #Eksperimen

# %%
all_results = run_experiments_single_dataset(df_kesepakatan, kolom_y='label_rendika_y')
# Out:
# ============================================================
# PREPARE FEATURES - Dataset
# ============================================================
#
# Dataset:
#   Shape fitur TF-IDF Train: (26948, 5000)
#   Shape fitur TF-IDF Test: (6737, 5000)
#   Jumlah fitur train: 5000
#   Jumlah fitur test: 5000
#
# ######################################################################
#   DATASET: Dataset
# ######################################################################
#
# >> Dataset | ROS | MLP Baseline
#   Run 1/3 (seed=42)... WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# WARNING:tensorflow:From C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Acc=0.8292 | F1=0.8287
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.8290 | F1=0.8236
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.8315 | F1=0.8243
#   >> RATA-RATA: Acc=0.8299 (±0.0012) | F1=0.8256 (±0.0023)
#
# >> Dataset | ROS | MLP Advanced
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.8533 | F1=0.8451
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.8487 | F1=0.8393
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.8511 | F1=0.8410
#   >> RATA-RATA: Acc=0.8511 (±0.0019) | F1=0.8418 (±0.0024)
#
# >> Dataset | ROS | MLP Keras Tuner
#   1/211 ━━━━━━━━━━━━━━━━━━━━ 13s 64ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.8367 | F1=0.8260
#   1/211 ━━━━━━━━━━━━━━━━━━━━ 13s 66ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.8367 | F1=0.8327
#   Run 3/3 (seed=456)...
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Acc=0.8410 | F1=0.8363
#   >> RATA-RATA: Acc=0.8382 (±0.0020) | F1=0.8317 (±0.0043)
#
# >> Dataset | ROS | Naive Bayes
#   Run 1/3 (seed=42)... Acc=0.7330 | F1=0.7573
#   Run 2/3 (seed=123)... Acc=0.7322 | F1=0.7565
#   Run 3/3 (seed=456)... Acc=0.7328 | F1=0.7571
#   >> RATA-RATA: Acc=0.7327 (±0.0003) | F1=0.7570 (±0.0003)
#
# >> Dataset | ROS | SVM
#   Run 1/3 (seed=42)... Acc=0.7836 | F1=0.7981
#   Run 2/3 (seed=123)... Acc=0.7855 | F1=0.8001
#   Run 3/3 (seed=456)... Acc=0.7815 | F1=0.7962
#   >> RATA-RATA: Acc=0.7835 (±0.0016) | F1=0.7982 (±0.0016)
#
# >> Dataset | ROS | Random Forest
#   Run 1/3 (seed=42)... Acc=0.8513 | F1=0.8434
#   Run 2/3 (seed=123)... Acc=0.8496 | F1=0.8419
#   Run 3/3 (seed=456)... Acc=0.8528 | F1=0.8445
#   >> RATA-RATA: Acc=0.8512 (±0.0013) | F1=0.8433 (±0.0011)
#
# >> Dataset | ROS | Logistic Regression
#   Run 1/3 (seed=42)... Acc=0.7845 | F1=0.8019
#   Run 2/3 (seed=123)... Acc=0.7778 | F1=0.7959
#   Run 3/3 (seed=456)... Acc=0.7858 | F1=0.8030
#   >> RATA-RATA: Acc=0.7827 (±0.0035) | F1=0.8002 (±0.0031)
#
# >> Dataset | SMOTE | MLP Baseline
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.8311 | F1=0.8188
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.8318 | F1=0.8211
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.8266 | F1=0.8166
#   >> RATA-RATA: Acc=0.8298 (±0.0023) | F1=0.8188 (±0.0018)
#
# >> Dataset | SMOTE | MLP Advanced
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.8234 | F1=0.8199
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Acc=0.8384 | F1=0.8345
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.8324 | F1=0.8299
#   >> RATA-RATA: Acc=0.8314 (±0.0062) | F1=0.8281 (±0.0061)
#
# >> Dataset | SMOTE | MLP Keras Tuner
#   Run 1/3 (seed=42)...
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.8241 | F1=0.8237
#   1/211 ━━━━━━━━━━━━━━━━━━━━ 12s 61ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.8366 | F1=0.8332
#   Run 3/3 (seed=456)...
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.8220 | F1=0.8178
#   >> RATA-RATA: Acc=0.8276 (±0.0064) | F1=0.8249 (±0.0064)
#
# >> Dataset | SMOTE | Naive Bayes
#   Run 1/3 (seed=42)... Acc=0.7477 | F1=0.7670
#   Run 2/3 (seed=123)... Acc=0.7434 | F1=0.7629
#   Run 3/3 (seed=456)... Acc=0.7481 | F1=0.7672
#   >> RATA-RATA: Acc=0.7464 (±0.0021) | F1=0.7657 (±0.0020)
#
# >> Dataset | SMOTE | SVM
#   Run 1/3 (seed=42)... Acc=0.8174 | F1=0.8247
#   Run 2/3 (seed=123)... Acc=0.8161 | F1=0.8238
#   Run 3/3 (seed=456)... Acc=0.8188 | F1=0.8260
#   >> RATA-RATA: Acc=0.8174 (±0.0011) | F1=0.8248 (±0.0009)
#
# >> Dataset | SMOTE | Random Forest
#   Run 1/3 (seed=42)... Acc=0.8370 | F1=0.8354
#   Run 2/3 (seed=123)... Acc=0.8391 | F1=0.8376
#   Run 3/3 (seed=456)... Acc=0.8375 | F1=0.8359
#   >> RATA-RATA: Acc=0.8379 (±0.0009) | F1=0.8363 (±0.0009)
#
# >> Dataset | SMOTE | Logistic Regression
#   Run 1/3 (seed=42)... Acc=0.8116 | F1=0.8225
#   Run 2/3 (seed=123)... Acc=0.8125 | F1=0.8235
#   Run 3/3 (seed=456)... Acc=0.8118 | F1=0.8224
#   >> RATA-RATA: Acc=0.8120 (±0.0004) | F1=0.8228 (±0.0005)
#
# >> Dataset | RUS | MLP Baseline
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.6694 | F1=0.7062
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.6433 | F1=0.6844
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.6724 | F1=0.7079
#   >> RATA-RATA: Acc=0.6617 (±0.0131) | F1=0.6995 (±0.0107)
#
# >> Dataset | RUS | MLP Advanced
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Acc=0.6682 | F1=0.7019
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.6534 | F1=0.6895
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.6127 | F1=0.6524
#   >> RATA-RATA: Acc=0.6448 (±0.0235) | F1=0.6812 (±0.0210)
#
# >> Dataset | RUS | MLP Keras Tuner
#   Run 1/3 (seed=42)...
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Acc=0.0457 | F1=0.0040
#   1/211 ━━━━━━━━━━━━━━━━━━━━ 12s 62ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.6550 | F1=0.6934
#   Run 3/3 (seed=456)...
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Acc=0.0457 | F1=0.0040
#   >> RATA-RATA: Acc=0.2488 (±0.2872) | F1=0.2338 (±0.3250)
#
# >> Dataset | RUS | Naive Bayes
#   Run 1/3 (seed=42)... Acc=0.6712 | F1=0.7107
#   Run 2/3 (seed=123)... Acc=0.6682 | F1=0.7091
#   Run 3/3 (seed=456)... Acc=0.6654 | F1=0.7048
#   >> RATA-RATA: Acc=0.6683 (±0.0024) | F1=0.7082 (±0.0025)
#
# >> Dataset | RUS | SVM
#   Run 1/3 (seed=42)... Acc=0.6921 | F1=0.7284
#   Run 2/3 (seed=123)... Acc=0.6867 | F1=0.7229
#   Run 3/3 (seed=456)... Acc=0.6874 | F1=0.7238
#   >> RATA-RATA: Acc=0.6887 (±0.0024) | F1=0.7250 (±0.0024)
#
# >> Dataset | RUS | Random Forest
#   Run 1/3 (seed=42)... Acc=0.7064 | F1=0.7409
#   Run 2/3 (seed=123)... Acc=0.6993 | F1=0.7344
#   Run 3/3 (seed=456)... Acc=0.6970 | F1=0.7328
#   >> RATA-RATA: Acc=0.7009 (±0.0040) | F1=0.7360 (±0.0035)
#
# >> Dataset | RUS | Logistic Regression
#   Run 1/3 (seed=42)... Acc=0.6985 | F1=0.7339
#   Run 2/3 (seed=123)... Acc=0.6895 | F1=0.7260
#   Run 3/3 (seed=456)... Acc=0.6941 | F1=0.7298
#   >> RATA-RATA: Acc=0.6940 (±0.0037) | F1=0.7299 (±0.0032)
#
# >> Dataset | SMOTEENN | MLP Baseline
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.3217 | F1=0.3165
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.3510 | F1=0.3551
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.3230 | F1=0.3131
#   >> RATA-RATA: Acc=0.3319 (±0.0136) | F1=0.3282 (±0.0190)
#
# >> Dataset | SMOTEENN | MLP Advanced
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.3435 | F1=0.3418
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.3352 | F1=0.3279
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Acc=0.3337 | F1=0.3276
#   >> RATA-RATA: Acc=0.3374 (±0.0043) | F1=0.3324 (±0.0066)
#
# >> Dataset | SMOTEENN | MLP Keras Tuner
#   1/211 ━━━━━━━━━━━━━━━━━━━━ 17s 83ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Acc=0.3464 | F1=0.3513
#   1/211 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.3726 | F1=0.3856
#   Run 3/3 (seed=456)...
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.3171 | F1=0.3007
#   >> RATA-RATA: Acc=0.3454 (±0.0227) | F1=0.3459 (±0.0349)
#
# >> Dataset | SMOTEENN | Naive Bayes
#   Run 1/3 (seed=42)... Acc=0.2336 | F1=0.1707
#   Run 2/3 (seed=123)... Acc=0.2338 | F1=0.1714
#   Run 3/3 (seed=456)... Acc=0.2339 | F1=0.1725
#   >> RATA-RATA: Acc=0.2338 (±0.0001) | F1=0.1715 (±0.0008)
#
# >> Dataset | SMOTEENN | SVM
#   Run 1/3 (seed=42)... Acc=0.3499 | F1=0.3536
#   Run 2/3 (seed=123)... Acc=0.3528 | F1=0.3579
#   Run 3/3 (seed=456)... Acc=0.3540 | F1=0.3578
#   >> RATA-RATA: Acc=0.3522 (±0.0017) | F1=0.3564 (±0.0020)
#
# >> Dataset | SMOTEENN | Random Forest
#   Run 1/3 (seed=42)... Acc=0.2719 | F1=0.2217
#   Run 2/3 (seed=123)... Acc=0.2730 | F1=0.2249
#   Run 3/3 (seed=456)... Acc=0.2728 | F1=0.2242
#   >> RATA-RATA: Acc=0.2726 (±0.0005) | F1=0.2236 (±0.0014)
#
# >> Dataset | SMOTEENN | Logistic Regression
#   Run 1/3 (seed=42)... Acc=0.2920 | F1=0.2643
#   Run 2/3 (seed=123)... Acc=0.2915 | F1=0.2641
#   Run 3/3 (seed=456)... Acc=0.2872 | F1=0.2587
#   >> RATA-RATA: Acc=0.2902 (±0.0021) | F1=0.2624 (±0.0026)
#
# >> Dataset | SMOTETomek | MLP Baseline
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.8300 | F1=0.8190
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.8275 | F1=0.8137
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Acc=0.8297 | F1=0.8176
#   >> RATA-RATA: Acc=0.8291 (±0.0011) | F1=0.8168 (±0.0022)
#
# >> Dataset | SMOTETomek | MLP Advanced
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.8369 | F1=0.8338
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.8330 | F1=0.8304
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.8318 | F1=0.8281
#   >> RATA-RATA: Acc=0.8339 (±0.0022) | F1=0.8308 (±0.0023)
#
# >> Dataset | SMOTETomek | MLP Keras Tuner
#   Run 1/3 (seed=42)...
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Acc=0.8309 | F1=0.8272
#   Run 2/3 (seed=123)...
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Acc=0.8323 | F1=0.8266
#   1/211 ━━━━━━━━━━━━━━━━━━━━ 13s 63ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Acc=0.8354 | F1=0.8308
#   >> RATA-RATA: Acc=0.8329 (±0.0019) | F1=0.8282 (±0.0018)
#
# >> Dataset | SMOTETomek | Naive Bayes
#   Run 1/3 (seed=42)... Acc=0.7474 | F1=0.7676
#   Run 2/3 (seed=123)... Acc=0.7435 | F1=0.7639
#   Run 3/3 (seed=456)... Acc=0.7480 | F1=0.7679
#   >> RATA-RATA: Acc=0.7463 (±0.0020) | F1=0.7664 (±0.0018)
#
# >> Dataset | SMOTETomek | SVM
#   Run 1/3 (seed=42)... Acc=0.8171 | F1=0.8245
#   Run 2/3 (seed=123)... Acc=0.8162 | F1=0.8240
#   Run 3/3 (seed=456)... Acc=0.8182 | F1=0.8255
#   >> RATA-RATA: Acc=0.8172 (±0.0008) | F1=0.8247 (±0.0006)
#
# >> Dataset | SMOTETomek | Random Forest
#   Run 1/3 (seed=42)... Acc=0.8388 | F1=0.8370
#   Run 2/3 (seed=123)... Acc=0.8382 | F1=0.8372
#   Run 3/3 (seed=456)... Acc=0.8389 | F1=0.8372
#   >> RATA-RATA: Acc=0.8387 (±0.0003) | F1=0.8371 (±0.0001)
#
# >> Dataset | SMOTETomek | Logistic Regression
#   Run 1/3 (seed=42)... Acc=0.8131 | F1=0.8241
#   Run 2/3 (seed=123)... Acc=0.8136 | F1=0.8244
#   Run 3/3 (seed=456)... Acc=0.8115 | F1=0.8223
#   >> RATA-RATA: Acc=0.8127 (±0.0009) | F1=0.8236 (±0.0009)

# %%
import json
import numpy as np

# %%
def convert_results(obj):
    if isinstance(obj, dict):
        return {k: convert_results(v) for k,v in obj.items()}
    elif isinstance(obj, list):
        return [convert_results(i) for i in obj]
    elif isinstance(obj,(np.float32, np.float64)):
        return float(obj)
    elif isinstance(obj, (np.int32, np.int64)):
        return int(obj)
    return obj


with open('results/all_results.json)','w') as f:
    json.dump(convert_results(all_results), f,indent=2)

#untuk load json
#with open('results/all_results.json', 'r') as f:
    #all_results =json.load(f)

# %%
from src.evaluation import print_all_metrics_table, find_best_model

# %%
# Langkah 1: Bungkus ulang variabel hasil running ke dalam dict baru
all_results_fixed = {'Dataset_A': all_results}

print("--- Menampilkan Tabel Metrik Berhasil ---")
# Langkah 2: Panggil tabel menggunakan variabel baru yang sudah dibungkus
print_all_metrics_table(all_results_fixed)

print("\n--- Mencari Model Terbaik ---")
# Langkah 3: Panggil fungsi pencari model terbaik dengan variabel baru yang benar
best_acc = find_best_model(all_results_fixed, metric='accuracy')
best_pre = find_best_model(all_results_fixed, metric='precision')
best_reca = find_best_model(all_results_fixed, metric='recall')
best_f1 = find_best_model(all_results_fixed, metric='f1')

# Langkah 4: Cetak hasilnya ke layar
print("Best Accuracy :", best_acc)
print("Best Precision:", best_pre)
print("Best Recall   :", best_reca)
print("Best F1-Score :", best_f1)
# Out:
# --- Menampilkan Tabel Metrik Berhasil ---
#
# ===============================================================================================
# RATA-RATA ACCURACY (3 RUNS) - Dataset_A
# ===============================================================================================
# Model                              ROS           SMOTE             RUS        SMOTEENN      SMOTETomek
# ------------------------------------------------------------------------------------------------------
# MLP Baseline            0.8299±0.0012  0.8298±0.0023  0.6617±0.0131  0.3319±0.0136  0.8291±0.0011
# MLP Advanced            0.8511±0.0019  0.8314±0.0062  0.6448±0.0235  0.3374±0.0043  0.8339±0.0022
# MLP Keras Tuner         0.8382±0.0020  0.8276±0.0064  0.2488±0.2872  0.3454±0.0227  0.8329±0.0019
# Naive Bayes             0.7327±0.0003  0.7464±0.0021  0.6683±0.0024  0.2338±0.0001  0.7463±0.0020
# SVM                     0.7835±0.0016  0.8174±0.0011  0.6887±0.0024  0.3522±0.0017  0.8172±0.0008
# Random Forest           0.8512±0.0013  0.8379±0.0009  0.7009±0.0040  0.2726±0.0005  0.8387±0.0003
# Logistic Regression     0.7827±0.0035  0.8120±0.0004  0.6940±0.0037  0.2902±0.0021  0.8127±0.0009
#
# ===============================================================================================
# RATA-RATA PRECISION (3 RUNS) - Dataset_A
# ===============================================================================================
# Model                              ROS           SMOTE             RUS        SMOTEENN      SMOTETomek
# ------------------------------------------------------------------------------------------------------
# MLP Baseline            0.8249±0.0056  0.8159±0.0023  0.7911±0.0014  0.7869±0.0039  0.8136±0.0020
# MLP Advanced            0.8400±0.0025  0.8256±0.0062  0.7996±0.0026  0.7928±0.0014  0.8284±0.0025
# MLP Keras Tuner         0.8288±0.0043  0.8229±0.0065  0.2663±0.3737  0.7962±0.0079  0.8253±0.0019
# Naive Bayes             0.8035±0.0004  0.8005±0.0018  0.7868±0.0038  0.8110±0.0000  0.8027±0.0016
# SVM                     0.8248±0.0016  0.8358±0.0007  0.8146±0.0030  0.8018±0.0008  0.8358±0.0004
# Random Forest           0.8433±0.0013  0.8381±0.0007  0.8264±0.0033  0.7946±0.0008  0.8391±0.0003
# Logistic Regression     0.8353±0.0023  0.8405±0.0008  0.8200±0.0018  0.8063±0.0009  0.8413±0.0011
#
# ===============================================================================================
# RATA-RATA RECALL (3 RUNS) - Dataset_A
# ===============================================================================================
# Model                              ROS           SMOTE             RUS        SMOTEENN      SMOTETomek
# ------------------------------------------------------------------------------------------------------
# MLP Baseline            0.8299±0.0012  0.8298±0.0023  0.6617±0.0131  0.3319±0.0136  0.8291±0.0011
# MLP Advanced            0.8511±0.0019  0.8314±0.0062  0.6448±0.0235  0.3374±0.0043  0.8339±0.0022
# MLP Keras Tuner         0.8382±0.0020  0.8276±0.0064  0.2488±0.2872  0.3454±0.0227  0.8329±0.0019
# Naive Bayes             0.7327±0.0003  0.7464±0.0021  0.6683±0.0024  0.2338±0.0001  0.7463±0.0020
# SVM                     0.7835±0.0016  0.8174±0.0011  0.6887±0.0024  0.3522±0.0017  0.8172±0.0008
# Random Forest           0.8512±0.0013  0.8379±0.0009  0.7009±0.0040  0.2726±0.0005  0.8387±0.0003
# Logistic Regression     0.7827±0.0035  0.8120±0.0004  0.6940±0.0037  0.2902±0.0021  0.8127±0.0009
#
# ===============================================================================================
# RATA-RATA F1 (3 RUNS) - Dataset_A
# ===============================================================================================
# Model                              ROS           SMOTE             RUS        SMOTEENN      SMOTETomek
# ------------------------------------------------------------------------------------------------------
# MLP Baseline            0.8256±0.0023  0.8188±0.0018  0.6995±0.0107  0.3282±0.0190  0.8168±0.0022
# MLP Advanced            0.8418±0.0024  0.8281±0.0061  0.6812±0.0210  0.3324±0.0066  0.8308±0.0023
# MLP Keras Tuner         0.8317±0.0043  0.8249±0.0064  0.2338±0.3250  0.3459±0.0349  0.8282±0.0018
# Naive Bayes             0.7570±0.0003  0.7657±0.0020  0.7082±0.0025  0.1715±0.0008  0.7664±0.0018
# SVM                     0.7982±0.0016  0.8248±0.0009  0.7250±0.0024  0.3564±0.0020  0.8247±0.0006
# Random Forest           0.8433±0.0011  0.8363±0.0009  0.7360±0.0035  0.2236±0.0014  0.8371±0.0001
# Logistic Regression     0.8002±0.0031  0.8228±0.0005  0.7299±0.0032  0.2624±0.0026  0.8236±0.0009
#
# --- Mencari Model Terbaik ---
#
# Dataset_A - Best accuracy:
#   Model    : Random Forest
#   Balancing: ROS
#   Score    : 0.8512 ± 0.0013
#
# Dataset_A - Best precision:
#   Model    : Random Forest
#   Balancing: ROS
#   Score    : 0.8433 ± 0.0013
#
# Dataset_A - Best recall:
#   Model    : Random Forest
#   Balancing: ROS
#   Score    : 0.8512 ± 0.0013
#
# Dataset_A - Best f1:
#   Model    : Random Forest
#   Balancing: ROS
#   Score    : 0.8433 ± 0.0011
# Best Accuracy : {'Dataset_A': {'dataset': 'Dataset_A', 'balancing': 'ROS', 'model': 'Random Forest', 'score_mean': np.float64(0.8512196328731879), 'score_std': np.float64(0.0012730374875334022)}}
# Best Precision: {'Dataset_A': {'dataset': 'Dataset_A', 'balancing': 'ROS', 'model': 'Random Forest', 'score_mean': np.float64(0.8432840499021802), 'score_std': np.float64(0.0012665080743936396)}}
# Best Recall   : {'Dataset_A': {'dataset': 'Dataset_A', 'balancing': 'ROS', 'model': 'Random Forest', 'score_mean': np.float64(0.8512196328731879), 'score_std': np.float64(0.0012730374875334022)}}
# Best F1-Score : {'Dataset_A': {'dataset': 'Dataset_A', 'balancing': 'ROS', 'model': 'Random Forest', 'score_mean': np.float64(0.8432832531757098), 'score_std': np.float64(0.001093168919377279)}}

# %%
import json

# Mengamankan hasil running 18 jam ke dalam file harddisk
with open('results/all_results.json', 'w') as f:
    json.dump(convert_results(all_results_fixed), f, indent=2)

# %%
print_all_metrics_table(all_results)
best_acc = find_best_model(all_results, metric='accuracy')
best_pre = find_best_model(all_results, metric='precision')
best_reca = find_best_model(all_results, metric='recall')
best_f1 = find_best_model(all_results, metric='f1')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 print_all_metrics_table(all_results)
# ----> 2 best_acc = find_best_model(all_results, metric='accuracy')
#       3 best_pre = find_best_model(all_results, metric='precision')
#       4 best_reca = find_best_model(all_results, metric='recall')
#
# File ~\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\src\evaluation.py:234, in find_best_model(all_results, metric)
#     232 for bal_name in all_results[ds_name]:
#     233     for model_name in all_results[ds_name][bal_name]:
# --> 234         score = all_results[ds_name][bal_name][model_name][metric]['mean']
#     235         if score > best_score:
#     236             best_score = score
#
# KeyError: 'accuracy'

# %%
# EValuasi

import os, gc
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import backend as K
import keras_tuner as kt

from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN,SMOTETomek

from src.models import (
    create_mlp_baseline, create_mlp_advance, make_tuner_builder,create_naive_bayes, create_logistic_regression, create_random_forest, create_svm, get_callbacks, MODEL_CONFIGS
)

from src.balancing import BALANCING_METHODS
from src.evaluation import (
    plot_confusion_matrix,
    plot_roc_curve,
    plot_learning_curve,
    print_all_metrics_table,
    print_classification_report,
    find_best_model
)

SEED=42

# %%
def prepare(df, kx, ky):
    X_tr, X_te, y_tr, y_te = train_test_split(df[kx], df[ky], test_size=0.2, random_state=SEED)

    tfidf = TfidfVectorizer(max_features=5000, min_df=2, max_df=0.95, ngram_range=(1,2))

    return tfidf.fit_transform(X_tr), tfidf.transform(X_te), to_categorical(y_tr,3), to_categorical(y_te,3)

data_prepared = {
    'Dataset_A': prepare(df_kesepakatan, 'clean_text', 'label'),
    #'Dataset_B': prepare(df_fadly, 'clean_text', 'label'),
}

# %%
DATASET_FOLDERS = {'Dataset_A': 'dataset_kesepakatan'}
total = len(data_prepared) * len(BALANCING_METHODS) * len(MODEL_CONFIGS)
counter = 0

for ds_name, (X_train, X_test, y_train_oh, y_test_oh) in data_prepared.items():
    y_true = np.argmax(y_test_oh, axis=1)

    for model_name, model_type in MODEL_CONFIGS.items():
        save_dir = f'results/{DATASET_FOLDERS[ds_name]}/{model_name.replace(" ","_")}'
        os.makedirs(save_dir, exist_ok=True)

        for bal_name, bal_class in BALANCING_METHODS.items():
            counter += 1
            tag = f'{model_name} + {bal_name} ({ds_name})'
            print(f"\n[{counter}/{total}] {tag}")

            # --- Balancing ---
            sampler = bal_class(random_state=SEED)
            X_bal, y_bal = sampler.fit_resample(X_train, y_train_oh)

            history = None
            y_pred_prob = None

            # --- Train ---
            if model_type == 'mlp_baseline':
                model = create_mlp_baseline(X_bal.shape[1])
                history = model.fit(X_bal, y_bal, epochs=50, batch_size=32,
                                    validation_split=0.15, callbacks=get_callbacks(), verbose=0)
                y_pred_prob = model.predict(X_test)
                y_pred = np.argmax(y_pred_prob, axis=1)
                del model; gc.collect(); K.clear_session()

            elif model_type == 'mlp_advance':
                model = create_mlp_advance(X_bal.shape[1])
                history = model.fit(X_bal, y_bal, epochs=50, batch_size=32,
                                    validation_split=0.15, callbacks=get_callbacks(), verbose=0)
                y_pred_prob = model.predict(X_test)
                y_pred = np.argmax(y_pred_prob, axis=1)
                del model; gc.collect(); K.clear_session()

            elif model_type == 'mlp_tuner':
                builder = make_tuner_builder(X_bal.shape[1])
                tuner = kt.RandomSearch(
                    builder, objective='val_accuracy', max_trials=5,
                    executions_per_trial=1,
                    directory=f'tuner_viz_{bal_name}_{ds_name}',
                    project_name='viz', overwrite=True
                )
                tuner.search(X_bal, y_bal, epochs=50, batch_size=32,
                             validation_split=0.15, callbacks=get_callbacks(), verbose=0)
                best_model = tuner.get_best_models(1)[0]
                y_pred_prob = best_model.predict(X_test)
                y_pred = np.argmax(y_pred_prob, axis=1)
                del best_model, tuner; gc.collect(); K.clear_session()

            else:  # sklearn
                y_bal_1d = np.argmax(y_bal, axis=1)
                if model_type == 'naive_bayes':
                    mdl = create_naive_bayes()
                elif model_type == 'svm':
                    mdl = create_svm(random_state=SEED)
                elif model_type == 'random_forest':
                    mdl = create_random_forest(random_state=SEED)
                elif model_type == 'logistic_regression':
                    mdl = create_logistic_regression(random_state=SEED)
                mdl.fit(X_bal, y_bal_1d)
                y_pred = mdl.predict(X_test)
                y_pred_prob = mdl.predict_proba(X_test)

            # --- Panggil fungsi evaluation.py ---
            prefix = f'{save_dir}/{bal_name}'

            print_classification_report(y_true, y_pred, title=tag)

            plot_confusion_matrix(y_true, y_pred, tag,
                                  save_path=f'{prefix}_cm.png')

            if y_pred_prob is not None:
                plot_roc_curve(y_true, y_pred_prob, tag,
                               save_path=f'{prefix}_roc.png')

            if history is not None:
                plot_learning_curve(history, tag,
                                    save_path=f'{prefix}_learning.png')

            print(f"  Acc={accuracy_score(y_true, y_pred):.4f} | F1={f1_score(y_true, y_pred, average='weighted'):.4f}")

print("\nSelesai!")
# Out:
# [1/35] MLP Baseline + ROS (Dataset_A)
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# --- Classification Report: MLP Baseline + ROS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.85      0.85      0.85      4790
#       Netral       0.63      0.63      0.63      1842
#      Positif       0.39      0.30      0.34       105
#
#     accuracy                           0.78      6737
#    macro avg       0.62      0.60      0.61      6737
# weighted avg       0.78      0.78      0.78      6737
#
#   Saved: results/dataset_kesepakatan/MLP_Baseline/ROS_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/ROS_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/ROS_learning.png
#   Acc=0.7848 | F1=0.7839
#
# [2/35] MLP Baseline + SMOTE (Dataset_A)
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# --- Classification Report: MLP Baseline + SMOTE (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.83      0.90      0.86      4790
#       Netral       0.68      0.55      0.61      1842
#      Positif       0.42      0.24      0.30       105
#
#     accuracy                           0.79      6737
#    macro avg       0.64      0.56      0.59      6737
# weighted avg       0.78      0.79      0.78      6737
#
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTE_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTE_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTE_learning.png
#   Acc=0.7926 | F1=0.7843
#
# [3/35] MLP Baseline + RUS (Dataset_A)
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# --- Classification Report: MLP Baseline + RUS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.86      0.72      0.78      4790
#       Netral       0.51      0.67      0.58      1842
#      Positif       0.21      0.64      0.32       105
#
#     accuracy                           0.70      6737
#    macro avg       0.52      0.67      0.56      6737
# weighted avg       0.75      0.70      0.72      6737
#
#   Saved: results/dataset_kesepakatan/MLP_Baseline/RUS_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/RUS_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/RUS_learning.png
#   Acc=0.7009 | F1=0.7170
#
# [4/35] MLP Baseline + SMOTEENN (Dataset_A)
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# --- Classification Report: MLP Baseline + SMOTEENN (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.92      0.15      0.25      4790
#       Netral       0.31      0.94      0.47      1842
#      Positif       0.12      0.52      0.20       105
#
#     accuracy                           0.37      6737
#    macro avg       0.45      0.54      0.31      6737
# weighted avg       0.74      0.37      0.31      6737
#
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTEENN_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTEENN_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTEENN_learning.png
#   Acc=0.3690 | F1=0.3101
#
# [5/35] MLP Baseline + SMOTETomek (Dataset_A)
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# --- Classification Report: MLP Baseline + SMOTETomek (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.83      0.89      0.86      4790
#       Netral       0.68      0.54      0.60      1842
#      Positif       0.34      0.30      0.32       105
#
#     accuracy                           0.79      6737
#    macro avg       0.61      0.58      0.59      6737
# weighted avg       0.78      0.79      0.78      6737
#
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTETomek_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTETomek_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Baseline/SMOTETomek_learning.png
#   Acc=0.7891 | F1=0.7818
#
# [6/35] MLP Advanced + ROS (Dataset_A)
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# --- Classification Report: MLP Advanced + ROS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.84      0.91      0.87      4790
#       Netral       0.71      0.57      0.63      1842
#      Positif       0.38      0.32      0.35       105
#
#     accuracy                           0.80      6737
#    macro avg       0.64      0.60      0.62      6737
# weighted avg       0.80      0.80      0.80      6737
#
#   Saved: results/dataset_kesepakatan/MLP_Advanced/ROS_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/ROS_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/ROS_learning.png
#   Acc=0.8045 | F1=0.7974
#
# [7/35] MLP Advanced + SMOTE (Dataset_A)
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Classification Report: MLP Advanced + SMOTE (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.86      0.85      0.85      4790
#       Netral       0.63      0.64      0.64      1842
#      Positif       0.32      0.36      0.34       105
#
#     accuracy                           0.78      6737
#    macro avg       0.60      0.62      0.61      6737
# weighted avg       0.79      0.78      0.79      6737
#
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTE_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTE_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTE_learning.png
#   Acc=0.7842 | F1=0.7851
#
# [8/35] MLP Advanced + RUS (Dataset_A)
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# --- Classification Report: MLP Advanced + RUS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.90      0.41      0.56      4790
#       Netral       0.37      0.87      0.52      1842
#      Positif       0.26      0.42      0.32       105
#
#     accuracy                           0.54      6737
#    macro avg       0.51      0.57      0.47      6737
# weighted avg       0.74      0.54      0.55      6737
#
#   Saved: results/dataset_kesepakatan/MLP_Advanced/RUS_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/RUS_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/RUS_learning.png
#   Acc=0.5367 | F1=0.5467
#
# [9/35] MLP Advanced + SMOTEENN (Dataset_A)
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Classification Report: MLP Advanced + SMOTEENN (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.91      0.12      0.20      4790
#       Netral       0.31      0.95      0.46      1842
#      Positif       0.13      0.51      0.21       105
#
#     accuracy                           0.35      6737
#    macro avg       0.45      0.53      0.29      6737
# weighted avg       0.73      0.35      0.28      6737
#
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTEENN_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTEENN_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTEENN_learning.png
#   Acc=0.3496 | F1=0.2753
#
# [10/35] MLP Advanced + SMOTETomek (Dataset_A)
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Classification Report: MLP Advanced + SMOTETomek (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.85      0.87      0.86      4790
#       Netral       0.66      0.61      0.63      1842
#      Positif       0.31      0.36      0.33       105
#
#     accuracy                           0.79      6737
#    macro avg       0.60      0.61      0.61      6737
# weighted avg       0.79      0.79      0.79      6737
#
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTETomek_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTETomek_roc.png
#   Saved: results/dataset_kesepakatan/MLP_Advanced/SMOTETomek_learning.png
#   Acc=0.7897 | F1=0.7881
#
# [11/35] MLP Keras Tuner + ROS (Dataset_A)
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Classification Report: MLP Keras Tuner + ROS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.86      0.85      0.86      4790
#       Netral       0.64      0.67      0.65      1842
#      Positif       0.43      0.42      0.42       105
#
#     accuracy                           0.79      6737
#    macro avg       0.64      0.64      0.64      6737
# weighted avg       0.80      0.79      0.79      6737
#
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/ROS_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/ROS_roc.png
#   Acc=0.7926 | F1=0.7939
#
# [12/35] MLP Keras Tuner + SMOTE (Dataset_A)
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Classification Report: MLP Keras Tuner + SMOTE (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.86      0.84      0.85      4790
#       Netral       0.62      0.66      0.64      1842
#      Positif       0.28      0.38      0.32       105
#
#     accuracy                           0.78      6737
#    macro avg       0.59      0.62      0.60      6737
# weighted avg       0.79      0.78      0.78      6737
#
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/SMOTE_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/SMOTE_roc.png
#   Acc=0.7809 | F1=0.7839
#
# [13/35] MLP Keras Tuner + RUS (Dataset_A)
#   1/211 ━━━━━━━━━━━━━━━━━━━━ 18s 89ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# --- Classification Report: MLP Keras Tuner + RUS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.90      0.34      0.49      4790
#       Netral       0.36      0.83      0.50      1842
#      Positif       0.10      0.65      0.17       105
#
#     accuracy                           0.48      6737
#    macro avg       0.45      0.61      0.39      6737
# weighted avg       0.74      0.48      0.49      6737
#
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/RUS_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/RUS_roc.png
#   Acc=0.4794 | F1=0.4912
#
# [14/35] MLP Keras Tuner + SMOTEENN (Dataset_A)
#   1/211 ━━━━━━━━━━━━━━━━━━━━ 21s 102ms/step
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# --- Classification Report: MLP Keras Tuner + SMOTEENN (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.96      0.05      0.10      4790
#       Netral       0.30      0.95      0.46      1842
#      Positif       0.09      0.57      0.15       105
#
#     accuracy                           0.31      6737
#    macro avg       0.45      0.53      0.24      6737
# weighted avg       0.77      0.31      0.20      6737
#
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/SMOTEENN_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/SMOTEENN_roc.png
#   Acc=0.3076 | F1=0.1997
#
# [15/35] MLP Keras Tuner + SMOTETomek (Dataset_A)
# C:\Users\Asus\Documents\Kuliah\9\Akhir\Codes\analisis-sentimen-pertamax-oplosan\.env\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# --- Classification Report: MLP Keras Tuner + SMOTETomek (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.85      0.85      0.85      4790
#       Netral       0.64      0.63      0.64      1842
#      Positif       0.28      0.40      0.33       105
#
#     accuracy                           0.78      6737
#    macro avg       0.59      0.63      0.61      6737
# weighted avg       0.79      0.78      0.79      6737
#
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/SMOTETomek_cm.png
#   Saved: results/dataset_kesepakatan/MLP_Keras_Tuner/SMOTETomek_roc.png
#   Acc=0.7848 | F1=0.7858
#
# [16/35] Naive Bayes + ROS (Dataset_A)
#
# --- Classification Report: Naive Bayes + ROS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.87      0.72      0.79      4790
#       Netral       0.53      0.68      0.60      1842
#      Positif       0.17      0.62      0.26       105
#
#     accuracy                           0.71      6737
#    macro avg       0.52      0.67      0.55      6737
# weighted avg       0.76      0.71      0.73      6737
#
#   Saved: results/dataset_kesepakatan/Naive_Bayes/ROS_cm.png
#   Saved: results/dataset_kesepakatan/Naive_Bayes/ROS_roc.png
#   Acc=0.7085 | F1=0.7270
#
# [17/35] Naive Bayes + SMOTE (Dataset_A)
#
# --- Classification Report: Naive Bayes + SMOTE (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.87      0.73      0.80      4790
#       Netral       0.54      0.69      0.60      1842
#      Positif       0.19      0.63      0.29       105
#
#     accuracy                           0.72      6737
#    macro avg       0.53      0.68      0.56      6737
# weighted avg       0.77      0.72      0.74      6737
#
#   Saved: results/dataset_kesepakatan/Naive_Bayes/SMOTE_cm.png
#   Saved: results/dataset_kesepakatan/Naive_Bayes/SMOTE_roc.png
#   Acc=0.7196 | F1=0.7360
#
# [18/35] Naive Bayes + RUS (Dataset_A)
#
# --- Classification Report: Naive Bayes + RUS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.84      0.66      0.74      4790
#       Netral       0.53      0.57      0.55      1842
#      Positif       0.08      0.79      0.15       105
#
#     accuracy                           0.64      6737
#    macro avg       0.49      0.68      0.48      6737
# weighted avg       0.74      0.64      0.68      6737
#
#   Saved: results/dataset_kesepakatan/Naive_Bayes/RUS_cm.png
#   Saved: results/dataset_kesepakatan/Naive_Bayes/RUS_roc.png
#   Acc=0.6403 | F1=0.6805
#
# [19/35] Naive Bayes + SMOTEENN (Dataset_A)
#
# --- Classification Report: Naive Bayes + SMOTEENN (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.98      0.05      0.09      4790
#       Netral       0.30      0.91      0.45      1842
#      Positif       0.08      0.71      0.15       105
#
#     accuracy                           0.29      6737
#    macro avg       0.45      0.56      0.23      6737
# weighted avg       0.78      0.29      0.19      6737
#
#   Saved: results/dataset_kesepakatan/Naive_Bayes/SMOTEENN_cm.png
#   Saved: results/dataset_kesepakatan/Naive_Bayes/SMOTEENN_roc.png
#   Acc=0.2927 | F1=0.1872
#
# [20/35] Naive Bayes + SMOTETomek (Dataset_A)
#
# --- Classification Report: Naive Bayes + SMOTETomek (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.87      0.73      0.80      4790
#       Netral       0.54      0.69      0.60      1842
#      Positif       0.18      0.63      0.28       105
#
#     accuracy                           0.72      6737
#    macro avg       0.53      0.68      0.56      6737
# weighted avg       0.77      0.72      0.74      6737
#
#   Saved: results/dataset_kesepakatan/Naive_Bayes/SMOTETomek_cm.png
#   Saved: results/dataset_kesepakatan/Naive_Bayes/SMOTETomek_roc.png
#   Acc=0.7198 | F1=0.7373
#
# [21/35] SVM + ROS (Dataset_A)
#
# --- Classification Report: SVM + ROS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.88      0.80      0.84      4790
#       Netral       0.60      0.72      0.66      1842
#      Positif       0.25      0.49      0.33       105
#
#     accuracy                           0.77      6737
#    macro avg       0.58      0.67      0.61      6737
# weighted avg       0.80      0.77      0.78      6737
#
#   Saved: results/dataset_kesepakatan/SVM/ROS_cm.png
#   Saved: results/dataset_kesepakatan/SVM/ROS_roc.png
#   Acc=0.7722 | F1=0.7806
#
# [22/35] SVM + SMOTE (Dataset_A)
#
# --- Classification Report: SVM + SMOTE (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.87      0.84      0.86      4790
#       Netral       0.66      0.68      0.67      1842
#      Positif       0.25      0.48      0.33       105
#
#     accuracy                           0.79      6737
#    macro avg       0.59      0.67      0.62      6737
# weighted avg       0.80      0.79      0.80      6737
#
#   Saved: results/dataset_kesepakatan/SVM/SMOTE_cm.png
#   Saved: results/dataset_kesepakatan/SVM/SMOTE_roc.png
#   Acc=0.7932 | F1=0.7980
#
# [23/35] SVM + RUS (Dataset_A)
#
# --- Classification Report: SVM + RUS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.86      0.65      0.74      4790
#       Netral       0.51      0.67      0.58      1842
#      Positif       0.10      0.70      0.17       105
#
#     accuracy                           0.65      6737
#    macro avg       0.49      0.67      0.50      6737
# weighted avg       0.76      0.65      0.69      6737
#
#   Saved: results/dataset_kesepakatan/SVM/RUS_cm.png
#   Saved: results/dataset_kesepakatan/SVM/RUS_roc.png
#   Acc=0.6539 | F1=0.6879
#
# [24/35] SVM + SMOTEENN (Dataset_A)
#
# --- Classification Report: SVM + SMOTEENN (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.94      0.14      0.24      4790
#       Netral       0.32      0.94      0.47      1842
#      Positif       0.11      0.59      0.19       105
#
#     accuracy                           0.37      6737
#    macro avg       0.46      0.56      0.30      6737
# weighted avg       0.76      0.37      0.30      6737
#
#   Saved: results/dataset_kesepakatan/SVM/SMOTEENN_cm.png
#   Saved: results/dataset_kesepakatan/SVM/SMOTEENN_roc.png
#   Acc=0.3657 | F1=0.3044
#
# [25/35] SVM + SMOTETomek (Dataset_A)
#
# --- Classification Report: SVM + SMOTETomek (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.87      0.84      0.86      4790
#       Netral       0.65      0.68      0.67      1842
#      Positif       0.24      0.48      0.32       105
#
#     accuracy                           0.79      6737
#    macro avg       0.59      0.67      0.62      6737
# weighted avg       0.80      0.79      0.80      6737
#
#   Saved: results/dataset_kesepakatan/SVM/SMOTETomek_cm.png
#   Saved: results/dataset_kesepakatan/SVM/SMOTETomek_roc.png
#   Acc=0.7916 | F1=0.7965
#
# [26/35] Random Forest + ROS (Dataset_A)
#
# --- Classification Report: Random Forest + ROS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.87      0.89      0.88      4790
#       Netral       0.71      0.67      0.69      1842
#      Positif       0.46      0.24      0.31       105
#
#     accuracy                           0.82      6737
#    macro avg       0.68      0.60      0.63      6737
# weighted avg       0.82      0.82      0.82      6737
#
#   Saved: results/dataset_kesepakatan/Random_Forest/ROS_cm.png
#   Saved: results/dataset_kesepakatan/Random_Forest/ROS_roc.png
#   Acc=0.8226 | F1=0.8193
#
# [27/35] Random Forest + SMOTE (Dataset_A)
#
# --- Classification Report: Random Forest + SMOTE (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.87      0.86      0.87      4790
#       Netral       0.67      0.69      0.68      1842
#      Positif       0.43      0.34      0.38       105
#
#     accuracy                           0.81      6737
#    macro avg       0.66      0.63      0.64      6737
# weighted avg       0.81      0.81      0.81      6737
#
#   Saved: results/dataset_kesepakatan/Random_Forest/SMOTE_cm.png
#   Saved: results/dataset_kesepakatan/Random_Forest/SMOTE_roc.png
#   Acc=0.8088 | F1=0.8090
#
# [28/35] Random Forest + RUS (Dataset_A)
#
# --- Classification Report: Random Forest + RUS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.94      0.58      0.72      4790
#       Netral       0.50      0.79      0.61      1842
#      Positif       0.09      0.74      0.16       105
#
#     accuracy                           0.64      6737
#    macro avg       0.51      0.70      0.50      6737
# weighted avg       0.81      0.64      0.68      6737
#
#   Saved: results/dataset_kesepakatan/Random_Forest/RUS_cm.png
#   Saved: results/dataset_kesepakatan/Random_Forest/RUS_roc.png
#   Acc=0.6400 | F1=0.6797
#
# [29/35] Random Forest + SMOTEENN (Dataset_A)
#
# --- Classification Report: Random Forest + SMOTEENN (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.96      0.06      0.12      4790
#       Netral       0.29      0.98      0.45      1842
#      Positif       0.20      0.50      0.28       105
#
#     accuracy                           0.32      6737
#    macro avg       0.48      0.52      0.28      6737
# weighted avg       0.76      0.32      0.21      6737
#
#   Saved: results/dataset_kesepakatan/Random_Forest/SMOTEENN_cm.png
#   Saved: results/dataset_kesepakatan/Random_Forest/SMOTEENN_roc.png
#   Acc=0.3197 | F1=0.2110
#
# [30/35] Random Forest + SMOTETomek (Dataset_A)
#
# --- Classification Report: Random Forest + SMOTETomek (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.87      0.87      0.87      4790
#       Netral       0.67      0.69      0.68      1842
#      Positif       0.43      0.36      0.39       105
#
#     accuracy                           0.81      6737
#    macro avg       0.66      0.64      0.65      6737
# weighted avg       0.81      0.81      0.81      6737
#
#   Saved: results/dataset_kesepakatan/Random_Forest/SMOTETomek_cm.png
#   Saved: results/dataset_kesepakatan/Random_Forest/SMOTETomek_roc.png
#   Acc=0.8099 | F1=0.8099
#
# [31/35] Logistic Regression + ROS (Dataset_A)
#
# --- Classification Report: Logistic Regression + ROS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.89      0.79      0.84      4790
#       Netral       0.61      0.72      0.66      1842
#      Positif       0.20      0.53      0.29       105
#
#     accuracy                           0.77      6737
#    macro avg       0.56      0.68      0.59      6737
# weighted avg       0.80      0.77      0.78      6737
#
#   Saved: results/dataset_kesepakatan/Logistic_Regression/ROS_cm.png
#   Saved: results/dataset_kesepakatan/Logistic_Regression/ROS_roc.png
#   Acc=0.7668 | F1=0.7788
#
# [32/35] Logistic Regression + SMOTE (Dataset_A)
#
# --- Classification Report: Logistic Regression + SMOTE (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.88      0.83      0.85      4790
#       Netral       0.65      0.69      0.67      1842
#      Positif       0.21      0.51      0.30       105
#
#     accuracy                           0.79      6737
#    macro avg       0.58      0.68      0.61      6737
# weighted avg       0.81      0.79      0.80      6737
#
#   Saved: results/dataset_kesepakatan/Logistic_Regression/SMOTE_cm.png
#   Saved: results/dataset_kesepakatan/Logistic_Regression/SMOTE_roc.png
#   Acc=0.7876 | F1=0.7953
#
# [33/35] Logistic Regression + RUS (Dataset_A)
#
# --- Classification Report: Logistic Regression + RUS (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.88      0.65      0.75      4790
#       Netral       0.52      0.71      0.60      1842
#      Positif       0.11      0.71      0.19       105
#
#     accuracy                           0.67      6737
#    macro avg       0.50      0.69      0.51      6737
# weighted avg       0.77      0.67      0.70      6737
#
#   Saved: results/dataset_kesepakatan/Logistic_Regression/RUS_cm.png
#   Saved: results/dataset_kesepakatan/Logistic_Regression/RUS_roc.png
#   Acc=0.6681 | F1=0.6994
#
# [34/35] Logistic Regression + SMOTEENN (Dataset_A)
#
# --- Classification Report: Logistic Regression + SMOTEENN (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.95      0.08      0.14      4790
#       Netral       0.32      0.94      0.48      1842
#      Positif       0.07      0.67      0.13       105
#
#     accuracy                           0.32      6737
#    macro avg       0.45      0.56      0.25      6737
# weighted avg       0.76      0.32      0.23      6737
#
#   Saved: results/dataset_kesepakatan/Logistic_Regression/SMOTEENN_cm.png
#   Saved: results/dataset_kesepakatan/Logistic_Regression/SMOTEENN_roc.png
#   Acc=0.3208 | F1=0.2318
#
# [35/35] Logistic Regression + SMOTETomek (Dataset_A)
#
# --- Classification Report: Logistic Regression + SMOTETomek (Dataset_A) ---
#               precision    recall  f1-score   support
#
#      Negatif       0.88      0.83      0.85      4790
#       Netral       0.65      0.69      0.67      1842
#      Positif       0.21      0.51      0.30       105
#
#     accuracy                           0.79      6737
#    macro avg       0.58      0.68      0.61      6737
# weighted avg       0.81      0.79      0.80      6737
#
#   Saved: results/dataset_kesepakatan/Logistic_Regression/SMOTETomek_cm.png
#   Saved: results/dataset_kesepakatan/Logistic_Regression/SMOTETomek_roc.png
#   Acc=0.7874 | F1=0.7952
#
# Selesai!
