# %%
import pandas as pd
from src.labeling import load_kesepakatan_data, show_label_distribution
from src.preprocessing import full_preprocessing

# %%
df_raw = load_kesepakatan_data('data/raw/data_kesepakatan.csv')
show_label_distribution(df_raw, 'Dataset Kesepakatan (Sebelum preprocessing)')

df = full_preprocessing(df_raw, kolom='full_text', use_stemming=True)
df.to_csv('data/processed/preprocessed_dataset_kesepakatan.csv', index=False)
show_label_distribution(df, 'Dataset Kesepakatan (Setelah Preprocessing)')
# Out:
# Dataset Kesepakatan -Total: len(df)
# label
# 0    27214
# 1     6166
# 2     1597
# Name: count, dtype: int64
#
# =============================================
# DISTRIBUSI KATEGORI - Dataset Kesepakatan (Sebelum preprocessing)
# =============================================
# Kategori       Jumlah   Persentase
# -----------------------------------
# Negatif         27214      77.81%
# Netral           6166      17.63%
# Positif          1597       4.57%
# -----------------------------------
# Total           34977      100.00%
# ....mulai case folding...
# ....mulai cleansing...
# ....mulai normalize slang...
# ....mulai remove stopword...
# ....mulai stemming...
# Preprocessing selesai. Total data: 34976
#
# =============================================
# DISTRIBUSI KATEGORI - Dataset Kesepakatan (Setelah Preprocessing)
# =============================================
# Kategori       Jumlah   Persentase
# -----------------------------------
# Negatif         27214      77.81%
# Netral           6165      17.63%
# Positif          1597       4.57%
# -----------------------------------
# Total           34976      100.00%
